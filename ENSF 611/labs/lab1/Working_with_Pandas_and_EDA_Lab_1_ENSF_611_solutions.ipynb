# %% [markdown]
# ## Filtering the data:
#
# The dataset I will be using: [link](https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/overview)
#
# Data Description: [link](https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/data)

# %%
import pandas as pd
import numpy as np

# %%
# read the dataset
df = pd.read_csv('./train.csv')
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
# show all the columns
pd.set_option('display.max_columns', None)

# %%
# see the first 5 records
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd       None
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng       None
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
# 3          ALQ         216          Unf           0        540          756
# 4          GLQ         655          Unf           0        490         1145
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
# 3       1717             1             0         1         0             3
# 4       2198             1             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
# 3     Detchd       1998.0          Unf           3         642         TA
# 4     Attchd       2000.0          RFn           3         836         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
# 3            0         0    NaN   NaN         NaN        0       2    2006
# 4            0         0    NaN   NaN         NaN        0      12    2008
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal     208500
# 1       WD        Normal     181500
# 2       WD        Normal     223500
# 3       WD       Abnorml     140000
# 4       WD        Normal     250000

# %%
# are there any duplicates?
df.duplicated().sum()
# Out:
# 0

# %%
# do we have any duplicates in Id? What about Neighborhood?
df.duplicated(subset=['Neighborhood']).sum()
# Out:
# 1435

# %%
# remove duplicates in Neighborhood by keeping only the first record for each
# Neighborhood and view the new dataset
# do not over-write the dataframe
df.drop_duplicates(subset=['Neighborhood'], keep='first').Neighborhood
# Out:
# 0      CollgCr
# 1      Veenker
# 3      Crawfor
# 4      NoRidge
# 5      Mitchel
# 6      Somerst
# 7       NWAmes
# 8      OldTown
# 9      BrkSide
# 10      Sawyer
# 11     NridgHt
# 14       NAmes
# 18     SawyerW
# 21      IDOTRR
# 23     MeadowV
# 39     Edwards
# 41      Timber
# 50     Gilbert
# 58     StoneBr
# 69     ClearCr
# 126    NPkVill
# 219    Blmngtn
# 225     BrDale
# 267      SWISU
# 599    Blueste
# Name: Neighborhood, dtype: object

# %%
# How many listings do we have?
len(df)
# Out:
# 1460

# %%
# How many columns do we have?
len(df.columns)
# Out:
# 81

# %%
# use .shape to see the column and rows length
print("The data size is : {} ".format(df.shape))
# Out:
# The data size is : (1460, 81)

# %%
# take a look at the datatypes
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
# get some stats in
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000
#
#         BsmtFinSF2    BsmtUnfSF  TotalBsmtSF     1stFlrSF     2ndFlrSF  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean     46.549315   567.240411  1057.429452  1162.626712   346.992466
# std     161.319273   441.866955   438.705324   386.587738   436.528436
# min       0.000000     0.000000     0.000000   334.000000     0.000000
# 25%       0.000000   223.000000   795.750000   882.000000     0.000000
# 50%       0.000000   477.500000   991.500000  1087.000000     0.000000
# 75%       0.000000   808.000000  1298.250000  1391.250000   728.000000
# max    1474.000000  2336.000000  6110.000000  4692.000000  2065.000000
#
#        LowQualFinSF    GrLivArea  BsmtFullBath  BsmtHalfBath     FullBath  \
# count   1460.000000  1460.000000   1460.000000   1460.000000  1460.000000
# mean       5.844521  1515.463699      0.425342      0.057534     1.565068
# std       48.623081   525.480383      0.518911      0.238753     0.550916
# min        0.000000   334.000000      0.000000      0.000000     0.000000
# 25%        0.000000  1129.500000      0.000000      0.000000     1.000000
# 50%        0.000000  1464.000000      0.000000      0.000000     2.000000
# 75%        0.000000  1776.750000      1.000000      0.000000     2.000000
# max      572.000000  5642.000000      3.000000      2.000000     3.000000
#
#           HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd   Fireplaces  \
# count  1460.000000   1460.000000   1460.000000   1460.000000  1460.000000
# mean      0.382877      2.866438      1.046575      6.517808     0.613014
# std       0.502885      0.815778      0.220338      1.625393     0.644666
# min       0.000000      0.000000      0.000000      2.000000     0.000000
# 25%       0.000000      2.000000      1.000000      5.000000     0.000000
# 50%       0.000000      3.000000      1.000000      6.000000     1.000000
# 75%       1.000000      3.000000      1.000000      7.000000     1.000000
# max       2.000000      8.000000      3.000000     14.000000     3.000000
#
#        GarageYrBlt   GarageCars   GarageArea   WoodDeckSF  OpenPorchSF  \
# count  1379.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean   1978.506164     1.767123   472.980137    94.244521    46.660274
# std      24.689725     0.747315   213.804841   125.338794    66.256028
# min    1900.000000     0.000000     0.000000     0.000000     0.000000
# 25%    1961.000000     1.000000   334.500000     0.000000     0.000000
# 50%    1980.000000     2.000000   480.000000     0.000000    25.000000
# 75%    2002.000000     2.000000   576.000000   168.000000    68.000000
# max    2010.000000     4.000000  1418.000000   857.000000   547.000000
#
#        EnclosedPorch    3SsnPorch  ScreenPorch     PoolArea       MiscVal  \
# count    1460.000000  1460.000000  1460.000000  1460.000000   1460.000000
# mean       21.954110     3.409589    15.060959     2.758904     43.489041
# std        61.119149    29.317331    55.757415    40.177307    496.123024
# min         0.000000     0.000000     0.000000     0.000000      0.000000
# 25%         0.000000     0.000000     0.000000     0.000000      0.000000
# 50%         0.000000     0.000000     0.000000     0.000000      0.000000
# 75%         0.000000     0.000000     0.000000     0.000000      0.000000
# max       552.000000   508.000000   480.000000   738.000000  15500.000000
#
#             MoSold       YrSold      SalePrice
# count  1460.000000  1460.000000    1460.000000
# mean      6.321918  2007.815753  180921.195890
# std       2.703626     1.328095   79442.502883
# min       1.000000  2006.000000   34900.000000
# 25%       5.000000  2007.000000  129975.000000
# 50%       6.000000  2008.000000  163000.000000
# 75%       8.000000  2009.000000  214000.000000
# max      12.000000  2010.000000  755000.000000

# %%
# describe only the SalePrice
df['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
# Convert 'YearBuilt' type to int
df['YearBuilt'] = pd.to_numeric(df['YearBuilt'], errors='coerce')

# %%
# which are the oldest houses?
df.sort_values('YearBuilt').head(2)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1349  1350          70       RM         50.0     5250   Pave  Pave      Reg
# 1137  1138          50       RL         54.0     6342   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1349         Lvl    AllPub    Inside       Gtl      OldTown       Norm
# 1137         Lvl    AllPub    Inside       Gtl       Sawyer      Feedr
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 1349       Norm     1Fam     2Story            8            5       1872
# 1137       Norm     1Fam     1.5Fin            5            8       1875
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 1349          1987     Gable  CompShg     MetalSd     MetalSd       None
# 1137          1996     Gable  CompShg     VinylSd     VinylSd       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 1349         0.0        TA        Gd     BrkTil       TA       Fa
# 1137         0.0        TA        Gd     CBlock       TA       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 1349           No          LwQ         259          Unf           0
# 1137           No          Unf           0          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 1349        425          684    OthW        Fa          N      SBrkr
# 1137        780          780    GasA        Gd          N      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 1349       938      1215           205       2358             0             0
# 1137       780       240             0       1020             0             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 1349         2         0             4             1          TA
# 1137         1         0             2             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 1349             8        Typ           0         NaN        NaN          NaN
# 1137             6        Typ           0         NaN        NaN          NaN
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 1349          NaN           0           0        NaN        NaN          Y
# 1137          NaN           0           0        NaN        NaN          N
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 1349           0           54             20          0            0
# 1137           0            0            176          0            0
#
#       PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 1349         0    NaN   NaN         NaN        0      12    2008       WD
# 1137         0    NaN   NaN         NaN        0       5    2010       WD
#
#      SaleCondition  SalePrice
# 1349        Normal     122000
# 1137        Normal      94000

# %%
# take a look at only one neighborhood (NoRidge)
df[df.Neighborhood == 'NoRidge']
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
#
# 517        Norm     1Fam     2Story            7            5       1996
# 524        Norm     1Fam     2Story            7            5       1996
# 541        Norm     1Fam     2Story            8            5       2000
# 564        Norm     1Fam     2Story            7            5       1992
# 654        Norm     1Fam     1Story            8            6       1995
# 661        Norm     1Fam     2Story            8            7       1994
# 684        Norm     1Fam     2Story            7            5       1998
# 691        Norm     1Fam     2Story           10            6       1994
# 718        Norm     1Fam     2Story            7            5       1993
# 748        Norm     1Fam     1Story            7            5       1996
# 759        Norm     1Fam     2Story            8            5       1995
# 763        Norm     1Fam     2Story            8            5       1999
# 792        Norm     1Fam     2Story            7            5       1996
# 981        Norm     1Fam     2Story            8            5       1998
# 990        Norm     1Fam     2Story            8            5       1997
# 1032       Norm     1Fam     2Story            8            7       1993
# 1057       Norm     1Fam     2Story            7            6       1994
# 1105       Norm     1Fam     2Story            8            5       1994
# 1169       Norm     1Fam     2Story           10            5       1995
# 1175       Norm     1Fam     1.5Fin            8            5       1992
# 1182       Norm     1Fam     2Story           10            5       1996
# 1187       Norm     1Fam     1Story            8            5       1994
# 1256       Norm     1Fam     1Story            8            5       1994
# 1302       Norm     1Fam     2Story            8            5       1994
# 1312       Norm     1Fam     2Story            8            5       1990
# 1313       Norm     1Fam     2Story            9            5       1999
# 1322       Norm     1Fam     2Story            7            5       1992
# 1353       Norm     1Fam     1.5Fin            8            5       1995
# 1373       Norm     1Fam     1Story           10            5       2001
# 1417       Norm     1Fam     2Story            8            5       1998
# 1426       Norm     1Fam     2Story            7            5       1994
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 4             2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 85            1992       Hip  CompShg     HdBoard     HdBoard    BrkFace
# 226           1995     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 231           1996     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 272           2007     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 318           1993     Gable  CompShg     HdBoard     HdBoard    BrkFace
# 359           1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 403           1998       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 423           1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 496           1993       Hip  CompShg     BrkFace     BrkFace       None
# 517           1997     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 524           1997     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 541           2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 564           2000     Gable  CompShg     HdBoard     HdBoard       None
# 654           1995       Hip  CompShg     MetalSd     MetalSd    BrkFace
# 661           2005       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 684           1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 691           1995     Gable  WdShngl     HdBoard     HdBoard    BrkFace
# 718           1994       Hip  CompShg     Wd Sdng     ImStucc    BrkFace
# 748           1996       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 759           1995     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 763           1999     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 792           1997     Gable  CompShg     MetalSd     MetalSd       None
# 981           1999       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 990           1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1032          1993     Gable  CompShg     MetalSd     MetalSd       None
# 1057          1994     Gable  CompShg     HdBoard     HdBoard       None
# 1105          1995     Gable  CompShg     HdBoard     HdBoard    BrkFace
# 1169          1996       Hip  CompShg     HdBoard     HdBoard    BrkFace
# 1175          2000       Hip  CompShg     HdBoard     HdBoard    BrkFace
# 1182          1996       Hip  CompShg     Wd Sdng     ImStucc       None
# 1187          1995     Gable  CompShg     ImStucc     ImStucc       None
# 1256          1994       Hip  CompShg     HdBoard     HdBoard    BrkFace
# 1302          1994       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 1312          1990     Gable  CompShg     Wd Sdng     Wd Sdng    BrkFace
# 1313          1999     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1322          1992     Gable  CompShg     HdBoard     HdBoard       None
# 1353          1996       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 1373          2002       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 1417          1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1426          1994     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 4          350.0        Gd        TA      PConc       Gd       TA
# 85         284.0        Gd        TA     CBlock       Gd       TA
# 226        290.0        Gd        TA      PConc       Gd       TA
# 231        506.0        Gd        TA      PConc       Gd       TA
# 272        348.0        Gd        TA      PConc       Gd       TA
# 318        256.0        Gd        TA      PConc       Gd       TA
# 359        530.0        Gd        TA      PConc       Gd       TA
# 403        650.0        Gd        TA      PConc       Gd       TA
# 423        473.0        Gd        TA      PConc       Gd       TA
# 496          0.0        Gd        TA      PConc       Gd       TA
# 517        921.0        Gd        TA      PConc       Gd       TA
# 524        594.0        Gd        TA      PConc       Gd       TA
# 541         72.0        Gd        TA      PConc       Gd       TA
# 564          0.0        Gd        TA      PConc       Gd       TA
# 654        660.0        Gd        Gd      PConc       Gd       TA
# 661        528.0        Gd        TA      PConc       Gd       Gd
# 684         30.0        Gd        TA      PConc       Gd       TA
# 691       1170.0        Ex        TA      PConc       Ex       TA
# 718        651.0        Gd        TA      PConc       Gd       TA
# 748        338.0        Gd        TA      PConc       Gd       TA
# 759        513.0        Gd        TA      PConc       Gd       TA
# 763        673.0        Gd        TA      PConc       Gd       TA
# 792          0.0        Gd        TA      PConc       Gd       TA
# 981        975.0        Gd        TA      PConc       Gd       TA
# 990        423.0        Gd        TA      PConc       Gd       TA
# 1032         0.0        Gd        Gd      PConc       Gd       Gd
# 1057         0.0        Gd        TA      PConc       Gd       TA
# 1105       362.0        Gd        TA      PConc       Ex       TA
# 1169      1378.0        Gd        Gd      PConc       Ex       TA
# 1175       337.0        Gd        TA      PConc       Gd       TA
# 1182         0.0        Gd        TA      PConc       Ex       TA
# 1187         0.0        Gd        TA      PConc       Gd       TA
# 1256       554.0        Gd        TA      PConc       Gd       TA
# 1302       391.0        Gd        TA      PConc       Gd       TA
# 1312       336.0        Gd        TA      PConc       Ex       TA
# 1313       165.0        Gd        TA      PConc       Gd       TA
# 1322         0.0        Gd        TA      PConc       Gd       TA
# 1353       579.0        Gd        TA      PConc       Gd       TA
# 1373       705.0        Ex        TA      PConc       Ex       TA
# 1417       731.0        Gd        TA      PConc       Gd       TA
# 1426       448.0        Gd        TA      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 4              Av          GLQ         655          Unf           0
# 85             No          Unf           0          Unf           0
# 226            No          GLQ         565          Unf           0
# 231            No          GLQ         689          Unf           0
# 272            No          GLQ         524          Unf           0
# 318            Gd          GLQ         987          Unf           0
# 359            Av          GLQ         956          Unf           0
# 403            No          Unf           0          Unf           0
# 423            No          GLQ         986          Unf           0
# 496            No          GLQ        1231          Unf           0
# 517            No          Unf           0          Unf           0
# 524            No          GLQ         719          Unf           0
# 541            No          Unf           0          Unf           0
# 564            No          GLQ         728          Unf           0
# 654            Gd          GLQ        1696          Unf           0
# 661            No          GLQ        1361          Rec         180
# 684            No          Unf           0          Unf           0
# 691            Gd          GLQ        1455          Unf           0
# 718            Gd          GLQ        1173          Unf           0
# 748            No          GLQ         919          Unf           0
# 759            Av          LwQ          56          ALQ          64
# 763            Mn          GLQ        1163          Unf           0
# 792            Av          GLQ         862          Unf           0
# 981            No          GLQ         854          Unf           0
# 990            No          GLQ        1074          Unf           0
# 1032           No          GLQ        1012          Unf           0
# 1057           No          GLQ         595          Unf           0
# 1105           Av          GLQ        1032          Unf           0
# 1169           Gd          GLQ        1387          Unf           0
# 1175           No          GLQ         700          Unf           0
# 1182           Av          GLQ        2096          Unf           0
# 1187           No          GLQ        1456          Unf           0
# 1256           Gd          GLQ        1314          Unf           0
# 1302           No          GLQ         740          Unf           0
# 1312           No          GLQ         482          Unf           0
# 1313           No          Unf           0          Unf           0
# 1322           No          GLQ         674          Unf           0
# 1353           Av          GLQ         816          Unf           0
# 1373           Gd          GLQ        1282          Unf           0
# 1417           Mn          GLQ         781          Unf           0
# 1426           No          GLQ        1000          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
#
# 792              8        Typ           1          TA     Attchd       1997.0
# 981              8        Typ           1          TA     Attchd       1998.0
# 990              7        Typ           1          TA     Attchd       1997.0
# 1032            10        Typ           1          TA     Attchd       1993.0
# 1057             7        Typ           1          Gd    BuiltIn       1994.0
# 1105             9        Typ           2          TA     Attchd       1994.0
# 1169            10        Typ           1          TA     Attchd       1995.0
# 1175             9        Typ           1          TA     Attchd       1992.0
# 1182            10        Typ           2          TA     Attchd       1996.0
# 1187             5        Typ           1          Fa     Attchd       1994.0
# 1256             7        Typ           1          TA     Attchd       1994.0
# 1302             8        Typ           1          TA     Attchd       1994.0
# 1312             9        Typ           1          Ex     Attchd       1990.0
# 1313            10        Typ           1          TA    BuiltIn       1999.0
# 1322             8        Typ           1          TA     Attchd       1992.0
# 1353             9        Typ           1          Ex     Attchd       1996.0
# 1373             8        Typ           2          Gd     Attchd       2001.0
# 1417             7        Typ           1          TA     Attchd       1998.0
# 1426             5        Typ           2          TA     Attchd       1994.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 4             RFn           3         836         TA         TA          Y
# 85            Unf           2         462         TA         TA          Y
# 226           RFn           3         721         TA         TA          Y
# 231           Fin           3         810         TA         TA          Y
# 272           Fin           3         671         TA         TA          Y
# 318           RFn           3         656         TA         TA          Y
# 359           RFn           2         592         TA         TA          Y
# 403           Fin           2         420         TA         TA          Y
# 423           Fin           3         696         TA         TA          Y
# 496           RFn           2         546         TA         TA          Y
# 517           RFn           3         889         TA         TA          Y
# 524           Fin           3         834         TA         TA          Y
# 541           Fin           3         648         TA         TA          Y
# 564           RFn           2         590         TA         TA          Y
# 654           Fin           3         839         TA         TA          Y
# 661           RFn           3         711         TA         TA          Y
# 684           Fin           2         486         TA         TA          Y
# 691           Fin           3         832         TA         TA          Y
# 718           RFn           3         983         TA         TA          Y
# 748           Fin           2         527         TA         TA          Y
# 759           RFn           3         752         TA         TA          Y
# 763           RFn           3         856         TA         TA          Y
# 792           Unf           2         455         TA         TA          Y
# 981           Fin           3         676         TA         TA          Y
# 990           Fin           3         870         TA         TA          Y
# 1032          RFn           3         796         TA         TA          Y
# 1057          Fin           2         467         TA         TA          Y
# 1105          RFn           2         712         TA         TA          Y
# 1169          Fin           3         807         TA         TA          Y
# 1175          Fin           2         541         TA         TA          Y
# 1182          Fin           3         813         TA         TA          Y
# 1187          RFn           3         757         TA         TA          Y
# 1256          Fin           2         691         TA         TA          Y
# 1302          RFn           3         844         TA         TA          Y
# 1312          RFn           2         750         Gd         Gd          Y
# 1313          Fin           3         779         TA         TA          Y
# 1322          RFn           2         564         TA         TA          Y
# 1353          Fin           3         666         TA         TA          Y
# 1373          RFn           3         804         TA         TA          Y
# 1417          Fin           3        1069         TA         TA          Y
# 1426          RFn           2         525         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 4            192           84              0          0            0
# 85           127           82              0          0            0
# 226          224          114              0          0            0
# 231            0          146            202          0            0
# 272          132           57              0          0            0
# 318          340           60            144          0            0
# 359          208           75              0          0          374
# 403          144          123              0          0            0
# 423            0           66              0          0            0
# 496          264           75            291          0            0
# 517          220            0              0          0            0
# 524          239           60              0          0            0
# 541            0           56              0          0            0
# 564            0           40              0          0            0
# 654          236           46              0          0            0
# 661          517           76              0          0            0
# 684            0           81              0          0            0
# 691          382           50              0          0            0
# 718          250          154            216          0            0
# 748          240           56            154          0            0
# 759          222           98              0          0            0
# 763            0          128              0          0          180
# 792          180          130              0          0            0
# 981          250            0              0          0            0
# 990            0           70              0          0            0
# 1032         209           55              0          0            0
# 1057         168           98              0          0            0
# 1105         186           32              0          0            0
# 1169         361           76              0          0            0
# 1175           0           33              0          0            0
# 1182         171           78              0          0            0
# 1187           0          114            192          0            0
# 1256         262           36              0          0            0
# 1302         309           78              0          0            0
# 1312         500            0              0          0            0
# 1313         668           30              0          0            0
# 1322         240           39              0          0            0
# 1353         283           86              0          0            0
# 1373         314          140              0          0            0
# 1417           0          126              0          0            0
# 1426         171          132              0          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 4            0    NaN    NaN         NaN        0      12    2008       WD
# 85           0    NaN    NaN         NaN        0       4    2006       WD
# 226          0    NaN    NaN         NaN        0       6    2007       WD
# 231          0    NaN    NaN         NaN        0       7    2009       WD
# 272          0    NaN    NaN         NaN        0       4    2010       WD
# 318          0    NaN    NaN         NaN        0       4    2009       WD
# 359          0    NaN    NaN         NaN        0       6    2006       WD
# 403          0    NaN    NaN         NaN        0       7    2006       WD
# 423          0    NaN    NaN         NaN        0       6    2008       WD
# 496          0    NaN    NaN         NaN        0       5    2007       WD
# 517          0    NaN    NaN         NaN        0       7    2009       WD
# 524          0    NaN    NaN         NaN        0       8    2007       WD
# 541          0    NaN    NaN         NaN        0       6    2007       WD
# 564          0    NaN    NaN         NaN        0       7    2006       WD
# 654          0    NaN    NaN         NaN        0       8    2008       WD
# 661          0    NaN    NaN         NaN        0       7    2009       WD
# 684          0    NaN    NaN         NaN        0       6    2010       WD
# 691          0    NaN    NaN         NaN        0       1    2007       WD
# 718          0    NaN    NaN         NaN        0       8    2008       WD
# 748          0    NaN    NaN         NaN        0       3    2010       WD
# 759          0    NaN    NaN         NaN        0      11    2007       WD
# 763          0    NaN    NaN         NaN        0       7    2009       WD
# 792          0    NaN    NaN         NaN        0       6    2007       WD
# 981          0    NaN    NaN         NaN        0       7    2009       WD
# 990          0    NaN    NaN         NaN        0       6    2006       WD
# 1032         0    NaN    NaN         NaN        0      11    2006       WD
# 1057         0    NaN    NaN         NaN        0       1    2009       WD
# 1105         0    NaN    NaN         NaN        0       4    2010       WD
# 1169         0    NaN    NaN         NaN        0       7    2006       WD
# 1175         0    NaN    NaN         NaN        0       4    2007       WD
# 1182       555     Ex  MnPrv         NaN        0       7    2007       WD
# 1187         0    NaN  GdPrv         NaN        0       7    2006       WD
# 1256         0    NaN    NaN         NaN        0       8    2008       WD
# 1302         0    NaN    NaN         NaN        0      12    2006       WD
# 1312         0    NaN    NaN         NaN        0       6    2007       WD
# 1313         0    NaN    NaN         NaN        0       5    2010       WD
# 1322         0    NaN    NaN         NaN        0       6    2010       WD
# 1353         0    NaN    NaN         NaN        0       3    2010       WD
# 1373         0    NaN    NaN         NaN        0       3    2007       WD
# 1417         0    NaN    NaN         NaN        0       5    2009       WD
# 1426         0    NaN    NaN         NaN        0       8    2008       WD
#
#      SaleCondition  SalePrice
# 4           Normal     250000
# 85          Normal     260000
# 226        Abnorml     290000
# 231         Normal     403000
# 272         Normal     290000
# 318         Normal     260000
# 359         Normal     280000
# 403        Abnorml     258000
# 423         Normal     315000
# 496         Normal     430000
# 517         Normal     265000
# 524         Normal     315750
# 541         Normal     248000
# 564         Normal     268000
# 654         Normal     350000
# 661         Normal     402000
# 684         Normal     221000
# 691         Normal     755000
# 718         Normal     341000
# 748         Normal     260400
# 759         Normal     290000
# 763         Normal     337000
# 792         Normal     269790
# 981         Normal     336000
# 990         Normal     348000
# 1032       Abnorml     310000
# 1057        Normal     248000
# 1105        Normal     325000
# 1169        Normal     625000
# 1175        Normal     285000
# 1182       Abnorml     745000
# 1187        Normal     262000
# 1256        Normal     301500
# 1302        Normal     290000
# 1312        Normal     302000
# 1313        Normal     333168
# 1322        Normal     190000
# 1353        Normal     410000
# 1373        Normal     466500
# 1417        Normal     340000
# 1426        Normal     271000

# %%
# take a look at only another neighborhood (NoRidge)
df[df.Neighborhood == 'Crawfor']
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 92      93          30       RL         80.0    13360   Pave  Grvl      IR1
# 113    114          20       RL          NaN    21000   Pave   NaN      Reg
# 114    115          70       RL         61.0     7259   Pave   NaN      IR1
# 181    182          70       RL         54.0     7588   Pave   NaN      Reg
# 190    191          70       RL         70.0    10570   Pave   NaN      Reg
# 218    219          50       RL          NaN    15660   Pave   NaN      IR1
# 251    252         120       RM         44.0     4750   Pave   NaN      IR1
# 299    300          20       RL         80.0    14000   Pave   NaN      Reg
# 300    301         190       RL         90.0    15750   Pave   NaN      Reg
# 407    408          70       RL         63.0    15576   Pave   NaN      Reg
# 417    418          70       RL         86.0    22420   Pave   NaN      IR1
# 438    439          30       RL         40.0     4280   Pave   NaN      Reg
# 463    464          70       RL         74.0    11988   Pave   NaN      IR1
# 503    504          20       RL        100.0    15602   Pave   NaN      IR1
# 514    515          45       RL         55.0    10594   Pave   NaN      Reg
# 519    520          70       RL         53.0    10918   Pave   NaN      Reg
# 529    530          20       RL          NaN    32668   Pave   NaN      IR1
# 598    599          20       RL         80.0    12984   Pave   NaN      Reg
# 608    609          70       RL         78.0    12168   Pave   NaN      Reg
# 657    658          70       RL         60.0     7200   Pave   NaN      Reg
# 669    670          30       RL         80.0    11600   Pave   NaN      Reg
# 673    674          20       RL        110.0    14442   Pave   NaN      Reg
# 726    727          20       RL          NaN    21695   Pave   NaN      IR1
# 852    853          75       RL         53.0     7128   Pave   NaN      Reg
# 860    861          50       RL         55.0     7642   Pave   NaN      Reg
# 907    908          50       RL         86.0    11500   Pave   NaN      IR1
# 913    914          90       RH         82.0     6270   Pave   NaN      Reg
# 955    956          90       RH         82.0     7136   Pave   NaN      IR1
# 966    967          50       RL        130.0     9600   Pave   NaN      IR1
# 1012  1013          70       RL         55.0    10592   Pave   NaN      Reg
# 1034  1035          30       RL         50.0     6305   Pave   NaN      Reg
# 1059  1060          50       RL          NaN    11275   Pave   NaN      IR1
# 1075  1076          70       RL         75.0    13125   Pave   NaN      Reg
# 1147  1148          70       RL         75.0    12000   Pave   NaN      Reg
# 1152  1153          20       RL         90.0    14115   Pave   NaN      IR1
# 1161  1162          20       RL          NaN    14778   Pave   NaN      IR1
# 1174  1175          70       RL         80.0    16560   Pave   NaN      IR1
# 1178  1179          50       RL         54.0     7681   Pave   NaN      IR1
# 1181  1182         120       RM         64.0     5587   Pave   NaN      IR1
# 1235  1236          70       RL         96.0    13132   Pave   NaN      Reg
# 1244  1245          70       RL          NaN    11435   Pave   NaN      IR1
# 1268  1269          50       RL          NaN    14100   Pave   NaN      IR1
# 1274  1275          50       RL         53.0     5362   Pave   NaN      Reg
# 1301  1302          70       RL          NaN     7500   Pave   NaN      IR1
# 1310  1311          20       RL        100.0    17500   Pave   NaN      Reg
# 1343  1344          50       RL         57.0     7558   Pave   NaN      Reg
# 1405  1406         120       RM         44.0     3842   Pave   NaN      IR1
# 1419  1420          20       RL          NaN    16381   Pave   NaN      IR1
# 1440  1441          70       RL         79.0    11526   Pave   NaN      IR1
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 3            Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 92           HLS    AllPub    Inside       Gtl      Crawfor       Norm
# 113          Bnk    AllPub    Corner       Gtl      Crawfor       Norm
# 114          Lvl    AllPub    Inside       Mod      Crawfor       Norm
# 181          Lvl    AllPub    Inside       Gtl      Crawfor       Norm
# 190          Bnk    AllPub    Inside       Mod      Crawfor       Norm
# 218          Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 251          HLS    AllPub    Inside       Mod      Crawfor       Norm
# 299          Lvl    AllPub    Inside       Gtl      Crawfor       Norm
# 300          Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 407          Lvl    AllPub    Inside       Gtl      Crawfor       Norm
# 417          Lvl    AllPub    Inside       Gtl      Crawfor      Feedr
# 438          Lvl    AllPub    Inside       Gtl      Crawfor       Norm
# 463          HLS    AllPub    Inside       Mod      Crawfor       Norm
# 503          Lvl    AllPub    Inside       Gtl      Crawfor       Norm
# 514          Lvl    AllPub    Inside       Gtl      Crawfor       Norm
# 519          Lvl    AllPub    Inside       Gtl      Crawfor       Norm
# 529          Lvl    AllPub   CulDSac       Gtl      Crawfor       Norm
# 598          Bnk    AllPub    Inside       Gtl      Crawfor       Norm
# 608          HLS    AllPub    Inside       Mod      Crawfor       Norm
# 657          HLS    AllPub    Inside       Mod      Crawfor       Norm
# 669          Lvl    AllPub    Inside       Gtl      Crawfor       Norm
# 673          Lvl    AllPub    Inside       Gtl      Crawfor       Norm
# 726          Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 852          Lvl    AllPub    Inside       Gtl      Crawfor       Norm
# 860          Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 907          Lvl    AllPub    Inside       Gtl      Crawfor       Norm
# 913          HLS    AllPub    Inside       Gtl      Crawfor       Norm
# 955          HLS    AllPub    Inside       Gtl      Crawfor       Norm
# 966          HLS    AllPub    Inside       Gtl      Crawfor       Norm
# 1012         Lvl    AllPub    Inside       Gtl      Crawfor       Norm
# 1034         Bnk    AllPub    Inside       Gtl      Crawfor       Norm
# 1059         HLS    AllPub    Corner       Mod      Crawfor       Norm
# 1075         Lvl    AllPub    Inside       Gtl      Crawfor       Norm
# 1147         Bnk    AllPub    Inside       Gtl      Crawfor       Norm
# 1152         Lvl    AllPub    Inside       Gtl      Crawfor       Norm
# 1161         Low    AllPub   CulDSac       Gtl      Crawfor       PosN
# 1174         Lvl    AllPub    Inside       Gtl      Crawfor       Norm
# 1178         Lvl    AllPub       FR2       Gtl      Crawfor       Norm
# 1181         HLS    AllPub    Inside       Mod      Crawfor       Norm
# 1235         Lvl    AllPub    Inside       Gtl      Crawfor       Norm
# 1244         HLS    AllPub    Corner       Mod      Crawfor       Norm
# 1268         Lvl    AllPub    Inside       Mod      Crawfor       Norm
# 1274         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 1301         Bnk    AllPub    Inside       Gtl      Crawfor       Norm
# 1310         Lvl    AllPub    Inside       Gtl      Crawfor       PosA
# 1343         Bnk    AllPub    Inside       Gtl      Crawfor       Norm
# 1405         HLS    AllPub    Inside       Mod      Crawfor       Norm
# 1419         Lvl    AllPub    Inside       Gtl      Crawfor       Norm
# 1440         Bnk    AllPub    Inside       Mod      Crawfor       Norm
# 1457         Lvl    AllPub    Inside       Gtl      Crawfor       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 3          Norm     1Fam     2Story            7            5       1915
# 92         Norm     1Fam     1Story            5            7       1921
# 113        Norm     1Fam     1Story            6            5       1953
# 114        Norm     1Fam     2Story            6            8       1945
# 181        Norm     1Fam     2Story            7            6       1920
# 190        Norm     1Fam     2Story            8            8       1932
# 218        Norm     1Fam     1.5Fin            7            9       1939
# 251        Norm   TwnhsE     1Story            8            5       2006
# 299        Norm     1Fam     1Story            6            8       1950
# 300        Norm   2fmCon     1Story            5            5       1953
# 407        Norm     1Fam     2Story            6            7       1915
# 417        Norm     1Fam     2Story            6            6       1918
Gable  CompShg     Wd Sdng     Wd Sdng       None
# 907           1987     Gable  CompShg     BrkFace     BrkFace       None
# 913           1950     Gable  CompShg     MetalSd     MetalSd       None
# 955           1950     Gable  CompShg     MetalSd     MetalSd    BrkFace
# 966           1950     Gable  CompShg     MetalSd     MetalSd       None
# 1012          1996       Hip  CompShg     Wd Sdng     Wd Sdng       None
# 1034          1950     Gable  CompShg     MetalSd     MetalSd       None
# 1059          1950     Gable  CompShg     MetalSd     MetalSd    BrkFace
# 1075          1984     Gable  CompShg     Wd Sdng     Wd Sdng       None
# 1147          1950     Gable  CompShg     MetalSd     MetalSd       None
# 1152          2004     Gable  CompShg       Stone       Stone       None
# 1161          2006       Hip  CompShg     HdBoard     HdBoard    BrkFace
# 1174          1950     Gable  CompShg     Wd Sdng     Wd Sdng       None
# 1178          1950     Gable  CompShg     Wd Sdng     Wd Sdng       None
# 1181          2008       Hip  CompShg     CemntBd     CmentBd      Stone
# 1235          1950     Gable  CompShg     Wd Sdng     Wd Sdng       None
# 1244          1950     Gable  CompShg     BrkFace      Stucco       None
# 1268          1997     Gable  CompShg      Stucco      Stucco    BrkFace
# 1274          2003     Gable  CompShg     Wd Sdng     Wd Shng       None
# 1301          1950     Gable  CompShg     Wd Sdng     Wd Sdng       None
# 1310          2002     Gable  CompShg     BrkFace     HdBoard       None
# 1343          1950     Gable  CompShg     BrkFace       Stone       None
# 1405          2005       Hip  CompShg     CemntBd     CmentBd      Stone
# 1419          1969     Gable  CompShg     Plywood     Plywood    BrkFace
# 1440          1994     Gable  CompShg     MetalSd     MetalSd       None
# 1457          2006     Gable  CompShg     CemntBd     CmentBd       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 3            0.0        TA        TA     BrkTil       TA       Gd
# 92           0.0        TA        Gd     BrkTil       Gd       TA
# 113        184.0        TA        Gd     CBlock       Gd       TA
# 114          0.0        TA        TA     CBlock       TA       TA
# 181          0.0        TA        TA     BrkTil       Fa       TA
# 190          0.0        Gd        TA     CBlock       Gd       Gd
# 218        312.0        Gd        Gd     CBlock       TA       TA
# 251        481.0        Gd        TA      PConc       Gd       TA
# 299          0.0        TA        Gd     CBlock       TA       TA
# 300         56.0        TA        TA     CBlock       TA       TA
# 407          0.0        TA        TA     BrkTil       Gd       TA
# 417          0.0        TA        TA     BrkTil       Gd       TA
# 438          0.0        TA        TA      PConc       TA       TA
# 463          0.0        TA        TA     CBlock       TA       TA
# 503          0.0        TA        TA     CBlock       TA       TA
# 514          0.0        TA        TA     BrkTil       TA       TA
# 519          0.0        Gd        TA     BrkTil       Gd       TA
# 529          NaN        Gd        TA      PConc       TA       TA
# 598        459.0        TA        TA     CBlock       Gd       TA
# 608          0.0        TA        TA      PConc       Gd       TA
# 657          0.0        TA        Fa     BrkTil       Gd       TA
# 669          0.0        TA        TA     BrkTil       Fa       TA
# 673        106.0        TA        TA      PConc       TA       TA
# 726        260.0        Gd        Gd     CBlock       Gd       TA
# 852          0.0        TA        Gd     CBlock       TA       TA
# 860          0.0        Gd        TA     BrkTil       TA       TA
# 907          0.0        Gd        TA     CBlock       Gd       TA
# 913          0.0        TA        TA     CBlock       TA       TA
# 955        423.0        TA        TA     CBlock       Gd       TA
# 966          0.0        Gd        Gd     BrkTil       TA       Fa
# 1012         0.0        TA        Gd      PConc       TA       Fa
# 1034         0.0        TA        Gd      PConc       Fa       Fa
# 1059       480.0        TA        TA     CBlock       TA       TA
# 1075         0.0        TA        TA     CBlock       TA       TA
# 1147         0.0        TA        TA     CBlock       TA       TA
# 1152         0.0        TA        TA      PConc       TA       TA
# 1161        72.0        Gd        TA     CBlock       TA       TA
# 463              6        Typ           1          Gd     Detchd       1939.0
# 503              6        Typ           2          TA     Attchd       1959.0
# 514              5        Typ           0         NaN     Detchd       1926.0
# 519              9        Typ           2          Gd     Detchd       1926.0
# 529              9       Maj1           2          TA     Attchd       1975.0
# 598              7        Typ           1          TA     Attchd       1977.0
# 608             10        Typ           2          Gd    Basment       1934.0
# 657              6        Typ           1          Gd     Attchd       1931.0
# 669              5        Typ           1          Gd     Detchd       1922.0
# 673              7        Typ           2          TA     Attchd       1957.0
# 726              5        Typ           1          Gd     Attchd       1988.0
# 852              7        Typ           2          Gd     Detchd       1941.0
# 860              7        Typ           1          Gd     Detchd       1925.0
# 907              6        Typ           1          Gd     Attchd       1936.0
# 913              8        Typ           0         NaN     2Types       1949.0
# 955              8        Typ           0         NaN     Attchd       1946.0
# 966              7       Min2           2          TA     Detchd       1940.0
# 1012             7        Typ           2          TA     Detchd       1923.0
# 1034             5        Typ           1          Gd    Basment       1938.0
# 1059             7        Typ           1          Gd     Detchd       1977.0
# 1075             6        Typ           2          Gd     Attchd       1940.0
# 1147             7        Typ           1          Gd     Attchd       1941.0
# 1152             6        Typ           1          Gd     Attchd       1956.0
# 1161             7        Typ           1          Gd     Detchd       1993.0
# 1174             9        Typ           1          Gd     Detchd       1932.0
# 1178             7        Typ           1          Gd     Detchd       1921.0
# 1181             5        Typ           1          Gd     Attchd       2008.0
# 1235             9        Typ           0         NaN     Detchd       1914.0
# 1244             7        Typ           2          Gd     Detchd       1931.0
# 1268            11        Typ           2          Gd    BuiltIn       1982.0
# 1274             8        Typ           1          Gd     Detchd       1985.0
# 1301             7        Typ           2          Gd     Attchd       1942.0
# 1310             7        Typ           2          TA     Attchd       1959.0
# 1343             9        Typ           1          TA     Detchd       1929.0
# 1405             5        Typ           1          Gd     Attchd       2004.0
# 1419             7        Typ           1          TA     Attchd       1969.0
# 1440            11       Min1           1          Gd     Detchd       1993.0
# 1457             9        Typ           2          Gd     Attchd       1941.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 3             Unf           3         642         TA         TA          Y
# 92            Unf           2         432         TA         TA          Y
# 113           Unf           2         450         TA         TA          Y
# 114           Unf           1         180         TA         TA          Y
# 181           Unf           1         216         Fa         TA          Y
# 190           Unf           2         440         TA         TA          Y
# 218           Unf           2         431         TA         TA          Y
# 251           Fin           2         538         TA         TA          Y
# 299           Unf           1         300         TA         TA          Y
# 300           Unf           1         375         TA         TA          Y
# 407           Unf           1         308         TA         TA          Y
# 417           Unf           3         864         TA         TA          N
# 438           Unf           1         352         Gd         TA          P
# 463           Unf           1         240         TA         TA          Y
# 503           Fin           2         484         TA         TA          Y
# 514           Unf           1         200         Po         Po          Y
# 519           Unf           1         282         TA         TA          Y
# 529           RFn           2         484         TA         TA          Y
# 598           Fin           2         621         TA         TA          Y
# 608           Unf           2         380         TA         TA          Y
# 657           RFn           1         270         TA         TA          P
# 669           Unf           1         252         TA         Fa          Y
# 673           Fin           2         416         TA         TA          Y
# 726           Fin           2         540         TA         TA          Y
# 852           Unf           1         240         TA         TA          Y
# 860           Unf           1         216         TA         TA          Y
# 907           Fin           1         180         Fa         TA          Y
# 913           Unf           3         871         TA         TA          Y
# 955           Unf           2         492         TA         TA          Y
# 966           Unf           1         256         TA         TA          Y
# 1012          Unf           1         180         TA         TA          Y
# 1034          Unf           1         240         Fa         TA          Y
# 1059          Unf           2         432         TA         Fa          Y
# 1075          Unf           1         240         TA         TA          Y
# 1147          Unf           1         234         TA         TA          Y
# 1152          Fin           2         470         TA         TA          Y
# 1161          Unf           2         924         TA         TA          Y
# 1174          Unf           2         360         TA         TA          Y
# 1178          Unf           1         186         Fa         TA          Y
# 1181          Fin           2         482         TA         TA          Y
# 1235          Unf           1         180         Fa         Fa          N
# 1244          Unf           2         400         TA         TA          Y
# 1268          Unf           3        1014         TA         TA          Y
# 1274          Unf           2         552         TA         TA          Y
# 1301          Unf           1         213         TA         TA          P
# 1310          Fin           2         567         TA         TA          Y
# 1343          Unf           2         342         Fa         Fa          Y
# 1405          Fin           2         482         TA         TA          Y
# 1419          RFn           2         540         TA         TA          Y
# 1440          Fin           2         672         TA         TA          Y
# 1457          RFn           1         252         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 3              0           35            272          0            0
# 92             0            0             44          0            0
# 113          166          120            192          0            0
# 114          224            0              0          0            0
# 181            0            0             40          0            0
# 190            0           74              0          0            0
# 218            0          119            150          0            0
# 251          123            0              0          0          153
# 299            0           36              0          0            0
# 300            0            0              0          0            0
# 407            0            0            160          0            0
# 417            0            0              0          0            0
# 438            0            0             34          0            0
# 463            0            0              0          0            0
# 503            0           54              0          0          161
# 514            0            0            112          0            0
# 519            0            0              0          0          145
# 529            0            0            200          0            0
# 598            0            0              0          0            0
# 608            0            0              0          0            0
# 657            0            0            112          0            0
# 669            0            0             67          0            0
# 673            0           87              0          0          200
# 726          292           44              0        182            0
# 852            0            0              0          0          126
# 860            0          240              0          0            0
# 907            0            0              0          0          322
# 913            0            0              0          0            0
# 955            0            0              0          0            0
# 966            0           70              0          0            0
# 1012          96            0            112          0           53
# 1034           0            0              0          0            0
# 1059           0            0             19          0            0
# 1075           0            0              0          0            0
# 1147           0            0              0          0            0
# 1152           0            0            280          0            0
# 1161         108            0              0        216            0
# 1174           0            0              0          0            0
# 1178         192            0            102          0            0
# 1181         162           53              0        153            0
# 1235         203           40              0          0            0
# 1244           0            0              0          0            0
# 1268         314           12              0          0            0
# 1274         242            0             81          0            0
# 1301           0            0              0          0          224
# 1310           0          207            162          0            0
# 1343           0            0              0          0            0
# 1405         128           53              0          0          155
# 1419           0           73            216          0            0
# 1440         431            0              0          0            0
# 1457           0           60              0          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 3            0    NaN    NaN         NaN        0       2    2006       WD
# 92           0    NaN    NaN         NaN        0       8    2009       WD
# 113          0    NaN  MnPrv         NaN        0      10    2007      COD
# 114          0    NaN  MnPrv         NaN        0       7    2007       WD
# 181          0    NaN    NaN         NaN        0       7    2006       WD
# 190          0    NaN    NaN         NaN        0      12    2007       WD
# 218          0    NaN    NaN         NaN        0       5    2008       WD
# 251          0    NaN    NaN         NaN        0      12    2007       WD
# 299          0    NaN  GdPrv         NaN        0       8    2009       WD
# 300          0    NaN    NaN         NaN        0       6    2006       WD
# 407          0    NaN    NaN         NaN        0       3    2008       WD
# 417          0    NaN    NaN         NaN        0      11    2007       WD
# 438          0    NaN  MnPrv         NaN        0       3    2007       WD
# 463          0    NaN    NaN         NaN        0       8    2008       WD
# 503          0    NaN   GdWo         NaN        0       3    2010       WD
# 514          0    NaN  MnPrv         NaN        0       6    2007       WD
# 519          0    NaN  MnPrv         NaN        0       6    2009       WD
# 529          0    NaN    NaN         NaN        0       3    2007       WD
# 598          0    NaN    NaN         NaN        0       3    2006       WD
# 608          0    NaN    NaN         NaN        0       9    2007       WD
# 657          0    NaN  MnPrv         NaN        0       2    2008       WD
# 669          0    NaN    NaN         NaN        0       7    2006       WD
# 673          0    NaN    NaN         NaN        0       6    2007       WD
# 726          0    NaN    NaN         NaN        0      12    2009       WD
# 852          0    NaN  MnPrv         NaN        0       8    2007       WD
# 860          0    NaN  GdPrv         NaN        0       6    2007       WD
# 907          0    NaN    NaN         NaN        0       6    2006       WD
# 913          0    NaN    NaN         NaN        0       8    2007       WD
# 955          0    NaN    NaN         NaN        0       8    2007       WD
# 966          0    NaN    NaN         NaN        0       6    2009       WD
# 1012         0    NaN    NaN         NaN        0       8    2007       WD
# 1034         0    NaN  MnPrv         NaN        0       6    2007       WD
# 1059         0    NaN    NaN         NaN        0       3    2007       WD
# 1075         0    NaN    NaN         NaN        0       7    2007      CWD
# 1147         0    NaN    NaN         NaN        0       7    2009       WD
# 1152         0    NaN    NaN         NaN        0       7    2006       WD
# 1161         0    NaN    NaN         NaN        0      11    2008       WD
# 1174         0    NaN    NaN         NaN        0       7    2006       WD
# 1178         0    NaN    NaN         NaN        0       7    2009       WD
# 1181         0    NaN    NaN         NaN        0      11    2008      New
# 1235         0    NaN    NaN         NaN        0       7    2006       WD
# 1244         0    NaN    NaN         NaN        0       6    2006       WD
# 1268         0    NaN   GdWo         NaN        0       5    2008       WD
# 1274         0    NaN    NaN         NaN        0      11    2007       WD
# 1301         0    NaN    NaN         NaN        0      11    2009       WD
# 1310         0    NaN    NaN         NaN        0       5    2010       WD
# 1343         0    NaN    NaN         NaN        0       3    2009       WD
# 1405         0    NaN    NaN         NaN        0       1    2008       WD
# 1419         0    NaN    NaN         NaN        0      12    2006       WD
# 1440         0    NaN    NaN         NaN        0       9    2008       WD
# 1457         0    NaN  GdPrv        Shed     2500       5    2010       WD
#
#      SaleCondition  SalePrice
# 3          Abnorml     140000
# 92          Normal     163500
# 113        Abnorml     217000
# 114         Normal     259500
# 181         Normal     200100
# 190         Normal     315000
# 218         Normal     311500
# 251         Family     235000
# 299         Family     158500
# 300         Normal     157000
# 407         Normal     177000
# 417         Normal     239000
# 438         Normal      90350
# 463         Normal     188700
# 503         Normal     289000
# 514         Normal      96500
# 519         Normal     234000
# 529         Alloca     200624
# 598         Normal     217500
# 608         Alloca     359100
# 657         Normal     149000
# 669         Normal     137500
# 673         Normal     257500
# 726         Normal     222000
# 852         Normal     164000
# 860         Normal     189950
# 907         Normal     250000
# 913         Normal     145000
# 955         Normal     145000
# 966         Normal     160000
# 1012        Normal     165000
# 1034        Normal     119750
# 1059        Normal     220000
# 1075        Normal     219500
# 1147        Normal     174500
# 1152       Abnorml     230000
# 1161        Normal     224000
# 1174        Normal     239000
# 1178        Normal     154900
# 1181       Partial     392500
# 1235        Normal     138887
# 1244        Normal     230000
# 1268        Normal     381000
# 1274        Normal     139000
# 1301        Normal     177500
# 1310        Normal     335000
# 1343        Normal     177000
# 1405        Normal     275000
# 1419        Normal     223000
# 1440        Normal     191000
# 1457        Normal     266500

# %%
# how many houses are there in this neighborhood?
len(df[df.Neighborhood == 'Crawfor'])
# Out:
# 51

# %%
# first house that was built in NoRidge neighborhood
df[df.Neighborhood == 'NoRidge'].sort_values('YearBuilt').head(2)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1312  1313          60       RL          NaN     9572   Pave   NaN      IR1
# 85      86          60       RL        121.0    16059   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1312         Lvl    AllPub    Inside       Gtl      NoRidge       Norm
# 85           Lvl    AllPub    Corner       Gtl      NoRidge       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 1312       Norm     1Fam     2Story            8            5       1990
# 85         Norm     1Fam     2Story            8            5       1991
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 1312          1990     Gable  CompShg     Wd Sdng     Wd Sdng    BrkFace
# 85            1992       Hip  CompShg     HdBoard     HdBoard    BrkFace
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 1312       336.0        Gd        TA      PConc       Ex       TA
# 85         284.0        Gd        TA     CBlock       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 1312           No          GLQ         482          Unf           0
# 85             No          Unf           0          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 1312        971         1453    GasA        Ex          Y      SBrkr
# 85         1288         1288    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 1312      1453      1357             0       2810             0             0
# 85        1301      1116             0       2417             0             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 1312         2         1             4             1          Gd
# 85           2         1             4             1          Gd
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 1312             9        Typ           1          Ex     Attchd       1990.0
# 85               9        Typ           1          TA     Attchd       1991.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 1312          RFn           2         750         Gd         Gd          Y
# 85            Unf           2         462         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 1312         500            0              0          0            0
# 85           127           82              0          0            0
#
#       PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 1312         0    NaN   NaN         NaN        0       6    2007       WD
# 85           0    NaN   NaN         NaN        0       4    2006       WD
#
#      SaleCondition  SalePrice
# 1312        Normal     302000
# 85          Normal     260000

# %%
# first house that was built in NoRidge neighborhood
df[df.Neighborhood == 'NoRidge'].sort_values('YearBuilt', ascending=False).head(2)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1373  1374          20       RL          NaN    11400   Pave   NaN      Reg
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1373         Lvl    AllPub    Inside       Gtl      NoRidge       Norm
# 4            Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 1373       Norm     1Fam     1Story           10            5       2001
# 4          Norm     1Fam     2Story            8            5       2000
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 1373          2002       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 4             2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 1373       705.0        Ex        TA      PConc       Ex       TA
# 4          350.0        Gd        TA      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 1373           Gd          GLQ        1282          Unf           0
# 4              Av          GLQ         655          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 1373       1351         2633    GasA        Ex          Y      SBrkr
# 4           490         1145    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 1373      2633         0             0       2633             1             0
# 4         1145      1053             0       2198             1             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 1373         2         1             2             1          Ex
# 4            2         1             4             1          Gd
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 1373             8        Typ           2          Gd     Attchd       2001.0
# 4                9        Typ           1          TA     Attchd       2000.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 1373          RFn           3         804         TA         TA          Y
# 4             RFn           3         836         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 1373         314          140              0          0            0
# 4            192           84              0          0            0
#
#       PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 1373         0    NaN   NaN         NaN        0       3    2007       WD
# 4            0    NaN   NaN         NaN        0      12    2008       WD
#
#      SaleCondition  SalePrice
# 1373        Normal     466500
# 4           Normal     250000

# %%
# Let's take a look at the NoRidge neighborhood for houses that
# were remodelled after 1998
df_noridge = df[df.Neighborhood == 'NoRidge']
df_noridge[df_noridge.YearRemodAdd >= 1998]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 272    273          60       RL         92.0    11764   Pave   NaN      IR1
# 359    360          60       RL         78.0    12011   Pave   NaN      IR1
# 403    404          60       RL         93.0    12090   Pave   NaN      Reg
# 423    424          60       RL         80.0     9200   Pave   NaN      Reg
# 541    542          60       RL          NaN    11000   Pave   NaN      Reg
# 564    565          60       RL          NaN    13346   Pave   NaN      IR1
# 661    662          60       RL         52.0    46589   Pave   NaN      IR2
# 684    685          60       RL         58.0    16770   Pave   NaN      IR2
# 763    764          60       RL         82.0     9430   Pave   NaN      Reg
# 981    982          60       RL         98.0    12203   Pave   NaN      IR1
# 990    991          60       RL         82.0     9452   Pave   NaN      Reg
# 1175  1176          50       RL         85.0    10678   Pave   NaN      Reg
# 1313  1314          60       RL        108.0    14774   Pave   NaN      IR1
# 1373  1374          20       RL          NaN    11400   Pave   NaN      Reg
# 1417  1418          60       RL          NaN    16545   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 4            Lvl    AllPub       FR2       Gtl      NoRidge       Norm
# 272          Lvl    AllPub   CulDSac       Gtl      NoRidge       Norm
# 359          Lvl    AllPub   CulDSac       Gtl      NoRidge       Norm
# 403          Lvl    AllPub    Corner       Gtl      NoRidge       Norm
# 423          Lvl    AllPub    Inside       Gtl      NoRidge       Norm
# 541          Lvl    AllPub       FR2       Gtl      NoRidge       Norm
# 564          Lvl    AllPub   CulDSac       Gtl      NoRidge       Norm
# 661          Lvl    AllPub   CulDSac       Gtl      NoRidge       Norm
# 684          Lvl    AllPub   CulDSac       Gtl      NoRidge       Norm
# 763          Lvl    AllPub    Inside       Gtl      NoRidge       Norm
# 981          Lvl    AllPub    Corner       Gtl      NoRidge       Norm
# 990          Lvl    AllPub    Inside       Gtl      NoRidge       Norm
# 1175         Lvl    AllPub    Inside       Gtl      NoRidge       Norm
# 1313         Lvl    AllPub    Corner       Gtl      NoRidge       Norm
# 1373         Lvl    AllPub    Inside       Gtl      NoRidge       Norm
# 1417         Lvl    AllPub    Inside       Gtl      NoRidge       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 4          Norm     1Fam     2Story            8            5       2000
# 272        Norm     1Fam     2Story            8            7       1999
# 359        Norm     1Fam     2Story            8            5       1998
# 403        Norm     1Fam     2Story            8            5       1998
# 423        Norm     1Fam     2Story            8            5       1998
# 541        Norm     1Fam     2Story            8            5       2000
# 564        Norm     1Fam     2Story            7            5       1992
# 661        Norm     1Fam     2Story            8            7       1994
# 684        Norm     1Fam     2Story            7            5       1998
# 763        Norm     1Fam     2Story            8            5       1999
# 981        Norm     1Fam     2Story            8            5       1998
# 990        Norm     1Fam     2Story            8            5       1997
# 1175       Norm     1Fam     1.5Fin            8            5       1992
# 1313       Norm     1Fam     2Story            9            5       1999
# 1373       Norm     1Fam     1Story           10            5       2001
# 1417       Norm     1Fam     2Story            8            5       1998
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 4             2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 272           2007     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 359           1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 403           1998       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 423           1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 541           2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 564           2000     Gable  CompShg     HdBoard     HdBoard       None
# 661           2005       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 684           1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 763           1999     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 981           1999       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 990           1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1175          2000       Hip  CompShg     HdBoard     HdBoard    BrkFace
# 1313          1999     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1373          2002       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 1417          1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 4          350.0        Gd        TA      PConc       Gd       TA
# 272        348.0        Gd        TA      PConc       Gd       TA
# 359        530.0        Gd        TA      PConc       Gd       TA
# 403        650.0        Gd        TA      PConc       Gd       TA
# 423        473.0        Gd        TA      PConc       Gd       TA
# 541         72.0        Gd        TA      PConc       Gd       TA
# 564          0.0        Gd        TA      PConc       Gd       TA
# 661        528.0        Gd        TA      PConc       Gd       Gd
# 684         30.0        Gd        TA      PConc       Gd       TA
# 763        673.0        Gd        TA      PConc       Gd       TA
# 981        975.0        Gd        TA      PConc       Gd       TA
# 990        423.0        Gd        TA      PConc       Gd       TA
# 1175       337.0        Gd        TA      PConc       Gd       TA
# 1313       165.0        Gd        TA      PConc       Gd       TA
# 1373       705.0        Ex        TA      PConc       Ex       TA
# 1417       731.0        Gd        TA      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 4              Av          GLQ         655          Unf           0
# 272            No          GLQ         524          Unf           0
# 359            Av          GLQ         956          Unf           0
# 403            No          Unf           0          Unf           0
# 423            No          GLQ         986          Unf           0
# 541            No          Unf           0          Unf           0
# 564            No          GLQ         728          Unf           0
# 661            No          GLQ        1361          Rec         180
# 684            No          Unf           0          Unf           0
# 763            Mn          GLQ        1163          Unf           0
# 981            No          GLQ         854          Unf           0
# 990            No          GLQ        1074          Unf           0
# 1175           No          GLQ         700          Unf           0
# 1313           No          Unf           0          Unf           0
# 1373           Gd          GLQ        1282          Unf           0
# 1417           Mn          GLQ         781          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 4           490         1145    GasA        Ex          Y      SBrkr
# 272         628         1152    GasA        Ex          Y      SBrkr
# 359         130         1086    GasA        Ex          Y      SBrkr
# 403        1141         1141    GasA        Gd          Y      SBrkr
# 423         484         1470    GasA        Gd          Y      SBrkr
# 541         969          969    GasA        Ex          Y      SBrkr
# 564         367         1095    GasA        Ex          Y      SBrkr
# 661          88         1629    GasA        Ex          Y      SBrkr
# 684        1195         1195    GasA        Gd          Y      SBrkr
# 763          89         1252    GasA        Ex          Y      SBrkr
# 981         371         1225    GasA        Ex          Y      SBrkr
# 990         322         1396    GasA        Ex          Y      SBrkr
# 1175        983         1683    GasA        Ex          Y      SBrkr
# 1313       1393         1393    GasA        Ex          Y      SBrkr
# 1373       1351         2633    GasA        Ex          Y      SBrkr
# 1417        503         1284    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 4         1145      1053             0       2198             1             0
# 272       1164      1106             0       2270             0             0
# 359       1086       838             0       1924             1             0
# 403       1165      1098             0       2263             0             0
# 423       1470      1160             0       2630             1             0
# 541        997      1288             0       2285             0             0
# 564       1166      1129             0       2295             1             0
# 661       1686       762             0       2448             1             0
# 684       1195       644             0       1839             0             0
# 763       1268      1097             0       2365             1             0
# 981       1276      1336             0       2612             1             0
# 990       1407       985             0       2392             1             0
# 1175      2129       743             0       2872             0             0
# 1313      1422      1177             0       2599             0             0
# 1373      2633         0             0       2633             1             0
# 1417      1310      1140             0       2450             1             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 4            2         1             4             1          Gd
# 272          2         1             4             1          Gd
# 359          2         1             3             1          Gd
# 403          2         1             4             1          Gd
# 423          2         1             4             1          Gd
# 541          2         1             4             1          Gd
# 564          2         1             4             1          Gd
# 661          2         1             4             1          Gd
# 684          2         1             4             1          TA
# 763          2         1             3             1          Gd
# 981          2         1             4             1          Gd
# 990          2         1             3             1          Gd
# 1175         2         1             4             1          Gd
# 1313         2         1             4             1          Gd
# 1373         2         1             2             1          Ex
# 1417         2         1             3             1          Gd
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 4                9        Typ           1          TA     Attchd       2000.0
# 272              9        Typ           1          Gd     Attchd       1999.0
# 359              7        Typ           1          TA     Attchd       1998.0
# 403             10        Typ           1          TA    BuiltIn       1998.0
# 423              8        Typ           1          TA     Attchd       1998.0
# 541              8        Typ           1          TA    BuiltIn       2000.0
# 564              9        Typ           1          TA     Attchd       1992.0
# 661              8        Typ           1          TA     Attchd       1994.0
# 684              7        Typ           0         NaN     Attchd       1998.0
# 763              8        Typ           1          Gd     Attchd       1999.0
# 981              8        Typ           1          TA     Attchd       1998.0
# 990              7        Typ           1          TA     Attchd       1997.0
# 1175             9        Typ           1          TA     Attchd       1992.0
# 1313            10        Typ           1          TA    BuiltIn       1999.0
# 1373             8        Typ           2          Gd     Attchd       2001.0
# 1417             7        Typ           1          TA     Attchd       1998.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 4             RFn           3         836         TA         TA          Y
# 272           Fin           3         671         TA         TA          Y
# 359           RFn           2         592         TA         TA          Y
# 403           Fin           2         420         TA         TA          Y
# 423           Fin           3         696         TA         TA          Y
# 541           Fin           3         648         TA         TA          Y
# 564           RFn           2         590         TA         TA          Y
# 661           RFn           3         711         TA         TA          Y
# 684           Fin           2         486         TA         TA          Y
# 763           RFn           3         856         TA         TA          Y
# 981           Fin           3         676         TA         TA          Y
# 990           Fin           3         870         TA         TA          Y
# 1175          Fin           2         541         TA         TA          Y
# 1313          Fin           3         779         TA         TA          Y
# 1373          RFn           3         804         TA         TA          Y
# 1417          Fin           3        1069         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 4            192           84              0          0            0
# 272          132           57              0          0            0
# 359          208           75              0          0          374
# 403          144          123              0          0            0
# 423            0           66              0          0            0
# 541            0           56              0          0            0
# 564            0           40              0          0            0
# 661          517           76              0          0            0
# 684            0           81              0          0            0
# 763            0          128              0          0          180
# 981          250            0              0          0            0
# 990            0           70              0          0            0
# 1175           0           33              0          0            0
# 1313         668           30              0          0            0
# 1373         314          140              0          0            0
# 1417           0          126              0          0            0
#
#       PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 4            0    NaN   NaN         NaN        0      12    2008       WD
# 272          0    NaN   NaN         NaN        0       4    2010       WD
# 359          0    NaN   NaN         NaN        0       6    2006       WD
# 403          0    NaN   NaN         NaN        0       7    2006       WD
# 423          0    NaN   NaN         NaN        0       6    2008       WD
# 541          0    NaN   NaN         NaN        0       6    2007       WD
# 564          0    NaN   NaN         NaN        0       7    2006       WD
# 661          0    NaN   NaN         NaN        0       7    2009       WD
# 684          0    NaN   NaN         NaN        0       6    2010       WD
# 763          0    NaN   NaN         NaN        0       7    2009       WD
# 981          0    NaN   NaN         NaN        0       7    2009       WD
# 990          0    NaN   NaN         NaN        0       6    2006       WD
# 1175         0    NaN   NaN         NaN        0       4    2007       WD
# 1313         0    NaN   NaN         NaN        0       5    2010       WD
# 1373         0    NaN   NaN         NaN        0       3    2007       WD
# 1417         0    NaN   NaN         NaN        0       5    2009       WD
#
#      SaleCondition  SalePrice
# 4           Normal     250000
# 272         Normal     290000
# 359         Normal     280000
# 403        Abnorml     258000
# 423         Normal     315000
# 541         Normal     248000
# 564         Normal     268000
# 661         Normal     402000
# 684         Normal     221000
# 763         Normal     337000
# 981         Normal     336000
# 990         Normal     348000
# 1175        Normal     285000
# 1313        Normal     333168
# 1373        Normal     466500
# 1417        Normal     340000

# %%
# another way of doing this?
df[(df.Neighborhood == 'NoRidge') & (df.YearRemodAdd >= 1998)]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 272    273          60       RL         92.0    11764   Pave   NaN      IR1
# 359    360          60       RL         78.0    12011   Pave   NaN      IR1
# 403    404          60       RL         93.0    12090   Pave   NaN      Reg
# 423    424          60       RL         80.0     9200   Pave   NaN      Reg
# 541    542          60       RL          NaN    11000   Pave   NaN      Reg
# 564    565          60       RL          NaN    13346   Pave   NaN      IR1
# 661    662          60       RL         52.0    46589   Pave   NaN      IR2
# 684    685          60       RL         58.0    16770   Pave   NaN      IR2
# 763    764          60       RL         82.0     9430   Pave   NaN      Reg
# 981    982          60       RL         98.0    12203   Pave   NaN      IR1
# 990    991          60       RL         82.0     9452   Pave   NaN      Reg
# 1175  1176          50       RL         85.0    10678   Pave   NaN      Reg
# 1313  1314          60       RL        108.0    14774   Pave   NaN      IR1
# 1373  1374          20       RL          NaN    11400   Pave   NaN      Reg
# 1417  1418          60       RL          NaN    16545   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 4            Lvl    AllPub       FR2       Gtl      NoRidge       Norm
# 272          Lvl    AllPub   CulDSac       Gtl      NoRidge       Norm
# 359          Lvl    AllPub   CulDSac       Gtl      NoRidge       Norm
# 403          Lvl    AllPub    Corner       Gtl      NoRidge       Norm
# 423          Lvl    AllPub    Inside       Gtl      NoRidge       Norm
# 541          Lvl    AllPub       FR2       Gtl      NoRidge       Norm
# 564          Lvl    AllPub   CulDSac       Gtl      NoRidge       Norm
# 661          Lvl    AllPub   CulDSac       Gtl      NoRidge       Norm
# 684          Lvl    AllPub   CulDSac       Gtl      NoRidge       Norm
# 763          Lvl    AllPub    Inside       Gtl      NoRidge       Norm
# 981          Lvl    AllPub    Corner       Gtl      NoRidge       Norm
# 990          Lvl    AllPub    Inside       Gtl      NoRidge       Norm
# 1175         Lvl    AllPub    Inside       Gtl      NoRidge       Norm
# 1313         Lvl    AllPub    Corner       Gtl      NoRidge       Norm
# 1373         Lvl    AllPub    Inside       Gtl      NoRidge       Norm
# 1417         Lvl    AllPub    Inside       Gtl      NoRidge       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 4          Norm     1Fam     2Story            8            5       2000
# 272        Norm     1Fam     2Story            8            7       1999
# 359        Norm     1Fam     2Story            8            5       1998
# 403        Norm     1Fam     2Story            8            5       1998
# 423        Norm     1Fam     2Story            8            5       1998
# 541        Norm     1Fam     2Story            8            5       2000
# 564        Norm     1Fam     2Story            7            5       1992
# 661        Norm     1Fam     2Story            8            7       1994
# 684        Norm     1Fam     2Story            7            5       1998
# 763        Norm     1Fam     2Story            8            5       1999
# 981        Norm     1Fam     2Story            8            5       1998
# 990        Norm     1Fam     2Story            8            5       1997
# 1175       Norm     1Fam     1.5Fin            8            5       1992
# 1313       Norm     1Fam     2Story            9            5       1999
# 1373       Norm     1Fam     1Story           10            5       2001
# 1417       Norm     1Fam     2Story            8            5       1998
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 4             2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 272           2007     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 359           1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 403           1998       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 423           1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 541           2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 564           2000     Gable  CompShg     HdBoard     HdBoard       None
# 661           2005       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 684           1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 763           1999     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 981           1999       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 990           1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1175          2000       Hip  CompShg     HdBoard     HdBoard    BrkFace
# 1313          1999     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1373          2002       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 1417          1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 4          350.0        Gd        TA      PConc       Gd       TA
# 272        348.0        Gd        TA      PConc       Gd       TA
# 359        530.0        Gd        TA      PConc       Gd       TA
# 403        650.0        Gd        TA      PConc       Gd       TA
# 423        473.0        Gd        TA      PConc       Gd       TA
# 541         72.0        Gd        TA      PConc       Gd       TA
# 564          0.0        Gd        TA      PConc       Gd       TA
# 661        528.0        Gd        TA      PConc       Gd       Gd
# 684         30.0        Gd        TA      PConc       Gd       TA
# 763        673.0        Gd        TA      PConc       Gd       TA
# 981        975.0        Gd        TA      PConc       Gd       TA
# 990        423.0        Gd        TA      PConc       Gd       TA
# 1175       337.0        Gd        TA      PConc       Gd       TA
# 1313       165.0        Gd        TA      PConc       Gd       TA
# 1373       705.0        Ex        TA      PConc       Ex       TA
# 1417       731.0        Gd        TA      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 4              Av          GLQ         655          Unf           0
# 272            No          GLQ         524          Unf           0
# 359            Av          GLQ         956          Unf           0
# 403            No          Unf           0          Unf           0
# 423            No          GLQ         986          Unf           0
# 541            No          Unf           0          Unf           0
# 564            No          GLQ         728          Unf           0
# 661            No          GLQ        1361          Rec         180
# 684            No          Unf           0          Unf           0
# 763            Mn          GLQ        1163          Unf           0
# 981            No          GLQ         854          Unf           0
# 990            No          GLQ        1074          Unf           0
# 1175           No          GLQ         700          Unf           0
# 1313           No          Unf           0          Unf           0
# 1373           Gd          GLQ        1282          Unf           0
# 1417           Mn          GLQ         781          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 4           490         1145    GasA        Ex          Y      SBrkr
# 272         628         1152    GasA        Ex          Y      SBrkr
# 359         130         1086    GasA        Ex          Y      SBrkr
# 403        1141         1141    GasA        Gd          Y      SBrkr
# 423         484         1470    GasA        Gd          Y      SBrkr
# 541         969          969    GasA        Ex          Y      SBrkr
# 564         367         1095    GasA        Ex          Y      SBrkr
# 661          88         1629    GasA        Ex          Y      SBrkr
# 684        1195         1195    GasA        Gd          Y      SBrkr
# 763          89         1252    GasA        Ex          Y      SBrkr
# 981         371         1225    GasA        Ex          Y      SBrkr
# 990         322         1396    GasA        Ex          Y      SBrkr
# 1175        983         1683    GasA        Ex          Y      SBrkr
# 1313       1393         1393    GasA        Ex          Y      SBrkr
# 1373       1351         2633    GasA        Ex          Y      SBrkr
# 1417        503         1284    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 4         1145      1053             0       2198             1             0
# 272       1164      1106             0       2270             0             0
# 359       1086       838             0       1924             1             0
# 403       1165      1098             0       2263             0             0
# 423       1470      1160             0       2630             1             0
# 541        997      1288             0       2285             0             0
# 564       1166      1129             0       2295             1             0
# 661       1686       762             0       2448             1             0
# 684       1195       644             0       1839             0             0
# 763       1268      1097             0       2365             1             0
# 981       1276      1336             0       2612             1             0
# 990       1407       985             0       2392             1             0
# 1175      2129       743             0       2872             0             0
# 1313      1422      1177             0       2599             0             0
# 1373      2633         0             0       2633             1             0
# 1417      1310      1140             0       2450             1             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 4            2         1             4             1          Gd
# 272          2         1             4             1          Gd
# 359          2         1             3             1          Gd
# 403          2         1             4             1          Gd
# 423          2         1             4             1          Gd
# 541          2         1             4             1          Gd
# 564          2         1             4             1          Gd
# 661          2         1             4             1          Gd
# 684          2         1             4             1          TA
# 763          2         1             3             1          Gd
# 981          2         1             4             1          Gd
# 990          2         1             3             1          Gd
# 1175         2         1             4             1          Gd
# 1313         2         1             4             1          Gd
# 1373         2         1             2             1          Ex
# 1417         2         1             3             1          Gd
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 4                9        Typ           1          TA     Attchd       2000.0
# 272              9        Typ           1          Gd     Attchd       1999.0
# 359              7        Typ           1          TA     Attchd       1998.0
# 403             10        Typ           1          TA    BuiltIn       1998.0
# 423              8        Typ           1          TA     Attchd       1998.0
# 541              8        Typ           1          TA    BuiltIn       2000.0
# 564              9        Typ           1          TA     Attchd       1992.0
# 661              8        Typ           1          TA     Attchd       1994.0
# 684              7        Typ           0         NaN     Attchd       1998.0
# 763              8        Typ           1          Gd     Attchd       1999.0
# 981              8        Typ           1          TA     Attchd       1998.0
# 990              7        Typ           1          TA     Attchd       1997.0
# 1175             9        Typ           1          TA     Attchd       1992.0
# 1313            10        Typ           1          TA    BuiltIn       1999.0
# 1373             8        Typ           2          Gd     Attchd       2001.0
# 1417             7        Typ           1          TA     Attchd       1998.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 4             RFn           3         836         TA         TA          Y
# 272           Fin           3         671         TA         TA          Y
# 359           RFn           2         592         TA         TA          Y
# 403           Fin           2         420         TA         TA          Y
# 423           Fin           3         696         TA         TA          Y
# 541           Fin           3         648         TA         TA          Y
# 564           RFn           2         590         TA         TA          Y
# 661           RFn           3         711         TA         TA          Y
# 684           Fin           2         486         TA         TA          Y
# 763           RFn           3         856         TA         TA          Y
# 981           Fin           3         676         TA         TA          Y
# 990           Fin           3         870         TA         TA          Y
# 1175          Fin           2         541         TA         TA          Y
# 1313          Fin           3         779         TA         TA          Y
# 1373          RFn           3         804         TA         TA          Y
# 1417          Fin           3        1069         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 4            192           84              0          0            0
# 272          132           57              0          0            0
# 359          208           75              0          0          374
# 403          144          123              0          0            0
# 423            0           66              0          0            0
# 541            0           56              0          0            0
# 564            0           40              0          0            0
# 661          517           76              0          0            0
# 684            0           81              0          0            0
# 763            0          128              0          0          180
# 981          250            0              0          0            0
# 990            0           70              0          0            0
# 1175           0           33              0          0            0
# 1313         668           30              0          0            0
# 1373         314          140              0          0            0
# 1417           0          126              0          0            0
#
#       PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 4            0    NaN   NaN         NaN        0      12    2008       WD
# 272          0    NaN   NaN         NaN        0       4    2010       WD
# 359          0    NaN   NaN         NaN        0       6    2006       WD
# 403          0    NaN   NaN         NaN        0       7    2006       WD
# 423          0    NaN   NaN         NaN        0       6    2008       WD
# 541          0    NaN   NaN         NaN        0       6    2007       WD
# 564          0    NaN   NaN         NaN        0       7    2006       WD
# 661          0    NaN   NaN         NaN        0       7    2009       WD
# 684          0    NaN   NaN         NaN        0       6    2010       WD
# 763          0    NaN   NaN         NaN        0       7    2009       WD
# 981          0    NaN   NaN         NaN        0       7    2009       WD
# 990          0    NaN   NaN         NaN        0       6    2006       WD
# 1175         0    NaN   NaN         NaN        0       4    2007       WD
# 1313         0    NaN   NaN         NaN        0       5    2010       WD
# 1373         0    NaN   NaN         NaN        0       3    2007       WD
# 1417         0    NaN   NaN         NaN        0       5    2009       WD
#
#      SaleCondition  SalePrice
# 4           Normal     250000
# 272         Normal     290000
# 359         Normal     280000
# 403        Abnorml     258000
# 423         Normal     315000
# 541         Normal     248000
# 564         Normal     268000
# 661         Normal     402000
# 684         Normal     221000
# 763         Normal     337000
# 981         Normal     336000
# 990         Normal     348000
# 1175        Normal     285000
# 1313        Normal     333168
# 1373        Normal     466500
# 1417        Normal     340000

# %%
# How many houses were built from 1950 through 1959?
len(df[(df.YearBuilt >= 1950) & (df.YearBuilt <= 1959)])
# Out:
# 167

# %%
# another way of doing this?
len(df[df.YearBuilt // 10 == 195])
# Out:
# 167

# %%
# how many fireplaces can a house have?
df.Fireplaces.unique()
# Out:
# array([0, 1, 2, 3], dtype=int64)

# %%
# how many types of kitchen quality do we have?
df.KitchenQual.unique()
# Out:
# array(['Gd', 'TA', 'Ex', 'Fa'], dtype=object)

# %%
# how many types of heating do we have?
df.Heating.unique()
# Out:
# array(['GasA', 'GasW', 'Grav', 'Wall', 'OthW', 'Floor'], dtype=object)

# %%
# how to view only houses that are heated by gas?
df[df.Heating.str.contains('Gas')].Heating
# Out:
# 0       GasA
# 1       GasA
# 2       GasA
# 3       GasA
# 4       GasA
#         ...
# 1455    GasA
# 1456    GasA
# 1457    GasA
# 1458    GasA
# 1459    GasA
# Name: Heating, Length: 1446, dtype: object

# %%
# using lambda and a function change 2Story to 2Storey and 1Story to 1Storey

# see what the values are in this column
print('before modification values are: ',  df.HouseStyle.unique())

# create a function that can change this value
def change_spelling(style_name):
    """
    changes the spelling of story to storey in a string
    input: string
    output: modified name of the style
    """
    if style_name == '2Story': return '2Storey'
    elif style_name == '1Story': return '1Storey'
    else: return style_name

# apply the changes on HouseStyle
df.loc[:, 'HouseStyle'] = df.loc[:, 'HouseStyle'].apply(lambda x: change_spelling(x))

# print the new values
print('after the modification values are: ',  df.HouseStyle.unique())
# Out:
# before modification values are:  ['2Story' '1Story' '1.5Fin' '1.5Unf' 'SFoyer' 'SLvl' '2.5Unf' '2.5Fin']
# after the modification values are:  ['2Storey' '1Storey' '1.5Fin' '1.5Unf' 'SFoyer' 'SLvl' '2.5Unf' '2.5Fin']

# %% [markdown]
# ## Your turn...
#
# Dataset: [link](https://www.kaggle.com/datasets/harshitshankhdhar/imdb-dataset-of-top-1000-movies-and-tv-shows)

# %%
# read the dataset
df_movies = pd.read_csv("./imdb_top_1000.csv")

# %%
# see the first few records
df_movies.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# 4  A jury holdout attempts to prevent a miscarria...        96.0
#
#                Director           Star1           Star2          Star3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#             Star4  No_of_Votes        Gross
# 0  William Sadler      2343110   28,341,469
# 1    Diane Keaton      1620367  134,966,411
# 2   Michael Caine      2303232  534,858,444
# 3    Diane Keaton      1129952   57,300,000
# 4    John Fiedler       689845    4,360,000

# %%
# How many movies are there?
len(df_movies)
# Out:
# 1000

# %%
# How many columns do we have?
len(df_movies.columns)
# Out:
# 16

# %%
# are there any duplicates?
df_movies.duplicated().sum()
# Out:
# 0

# %%
# are there any duplicates in the Released_Year column?
df_movies.duplicated(subset=['Released_Year']).sum()
# Out:
# 900

# %%
# take a look at the datatypes
df_movies.dtypes
# Out:
# Poster_Link       object
# Series_Title      object
# Released_Year     object
# Certificate       object
# Runtime           object
# Genre             object
# IMDB_Rating      float64
# Overview          object
# Meta_score       float64
# Director          object
# Star1             object
# Star2             object
# Star3             object
# Star4             object
# No_of_Votes        int64
# Gross             object
# dtype: object

# %%
# Convert 'Released_Year' to int
df_movies['Released_Year'] = pd.to_numeric(df_movies['Released_Year'], errors='coerce')

# Convert 'Gross' to float
df_movies['Gross'] = df_movies['Gross'].str.replace(',', '').astype(float)

# Now, you can check the data types of your DataFrame
print(df_movies.dtypes)
# Out:
# Poster_Link       object
# Series_Title      object
# Released_Year    float64
# Certificate       object
# Runtime           object
# Genre             object
# IMDB_Rating      float64
# Overview          object
# Meta_score       float64
# Director          object
# Star1             object
# Star2             object
# Star3             object
# Star4             object
# No_of_Votes        int64
# Gross            float64
# dtype: object

# %%
# take a look at the record for Fight Club
df_movies[df_movies.Series_Title == 'Fight Club']
# Out:
#                                          Poster_Link Series_Title  \
# 9  https://m.media-amazon.com/images/M/MV5BMmEzNT...   Fight Club
#
#    Released_Year Certificate  Runtime  Genre  IMDB_Rating  \
# 9         1999.0           A  139 min  Drama          8.8
#
#                                             Overview  Meta_score  \
# 9  An insomniac office worker and a devil-may-car...        66.0
#
#         Director      Star1          Star2      Star3         Star4  \
# 9  David Fincher  Brad Pitt  Edward Norton  Meat Loaf  Zach Grenier
#
#    No_of_Votes       Gross
# 9      1854740  37030102.0

# %%
# which are the movies released after the year 2000?
df_movies[df_movies.Released_Year > 2000]
# Out:
#                                            Poster_Link  \
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 5    https://m.media-amazon.com/images/M/MV5BNzA5ZD...
# 8    https://m.media-amazon.com/images/M/MV5BMjAxMz...
# 10   https://m.media-amazon.com/images/M/MV5BN2EyZj...
# 13   https://m.media-amazon.com/images/M/MV5BZGMxZT...
# ..                                                 ...
# 947  https://m.media-amazon.com/images/M/MV5BNjQ3NW...
# 948  https://m.media-amazon.com/images/M/MV5BMTAxMD...
# 949  https://m.media-amazon.com/images/M/MV5BYjg5ZD...
# 950  https://m.media-amazon.com/images/M/MV5BYWFlY2...
# 951  https://m.media-amazon.com/images/M/MV5BZTI3Yz...
#
#                                           Series_Title  Released_Year  \
# 2                                      The Dark Knight         2008.0
# 5        The Lord of the Rings: The Return of the King         2003.0
# 8                                            Inception         2010.0
# 10   The Lord of the Rings: The Fellowship of the Ring         2001.0
# 13               The Lord of the Rings: The Two Towers         2002.0
# ..                                                 ...            ...
# 947              Harry Potter and the Sorcerer's Stone         2001.0
# 948                                         The Others         2001.0
# 949                                               Blow         2001.0
# 950                                 Enemy at the Gates         2001.0
# 951                                    Minority Report         2002.0
#
#     Certificate  Runtime                       Genre  IMDB_Rating  \
# 2            UA  152 min        Action, Crime, Drama          9.0
# 5             U  201 min    Action, Adventure, Drama          8.9
# 8            UA  148 min   Action, Adventure, Sci-Fi          8.8
# 10            U  178 min    Action, Adventure, Drama          8.8
# 13           UA  179 min    Action, Adventure, Drama          8.7
# ..          ...      ...                         ...          ...
# 947           U  152 min  Adventure, Family, Fantasy          7.6
# 948       PG-13  101 min   Horror, Mystery, Thriller          7.6
# 949           R  124 min     Biography, Crime, Drama          7.6
# 950           A  131 min         Drama, History, War          7.6
# 951           A  145 min      Action, Crime, Mystery          7.6
#
#                                               Overview  Meta_score  \
# 2    When the menace known as the Joker wreaks havo...        84.0
# 5    Gandalf and Aragorn lead the World of Men agai...        94.0
# 8    A thief who steals corporate secrets through t...        74.0
# 10   A meek Hobbit from the Shire and eight compani...        92.0
# 13   While Frodo and Sam edge closer to Mordor with...        87.0
# ..                                                 ...         ...
# 947  An orphaned boy enrolls in a school of wizardr...        64.0
# 948  A woman who lives in her darkened old family h...        74.0
# 949  The story of how George Jung, along with the M...        52.0
# 950  A Russian and a German sniper play a game of c...        53.0
# 951  In a future where a special police unit is abl...        80.0
#
#                 Director              Star1                  Star2  \
# 2      Christopher Nolan     Christian Bale           Heath Ledger
# 5          Peter Jackson        Elijah Wood        Viggo Mortensen
# 8      Christopher Nolan  Leonardo DiCaprio   Joseph Gordon-Levitt
# 10         Peter Jackson        Elijah Wood           Ian McKellen
# 13         Peter Jackson        Elijah Wood           Ian McKellen
# ..                   ...                ...                    ...
# 947       Chris Columbus   Daniel Radcliffe           Rupert Grint
# 948   Alejandro Amenábar      Nicole Kidman  Christopher Eccleston
# 949            Ted Demme        Johnny Depp          Penélope Cruz
# 950  Jean-Jacques Annaud           Jude Law              Ed Harris
# 951     Steven Spielberg         Tom Cruise          Colin Farrell
#
#                  Star3             Star4  No_of_Votes        Gross
# 2        Aaron Eckhart     Michael Caine      2303232  534858444.0
# 5         Ian McKellen     Orlando Bloom      1642758  377845905.0
# 8          Elliot Page      Ken Watanabe      2067042  292576195.0
# 10       Orlando Bloom         Sean Bean      1661481  315544750.0
# 13     Viggo Mortensen     Orlando Bloom      1485555  342551365.0
# ..                 ...               ...          ...          ...
# 947     Richard Harris      Maggie Smith       658185  317575550.0
# 948  Fionnula Flanagan      Alakina Mann       337651   96522687.0
# 949     Franka Potente  Rachel Griffiths       240714   52990775.0
# 950     Joseph Fiennes      Rachel Weisz       243729   51401758.0
# 951    Samantha Morton     Max von Sydow       508417  132072926.0
#
# [466 rows x 16 columns]

# %%
# which are the 2 most famouse ones? (look at the number of votes!)
df_movies.sort_values(by="No_of_Votes", ascending=False).head(2)
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
#
#                Series_Title  Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption         1994.0           A  142 min
# 2           The Dark Knight         2008.0          UA  152 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 2  Action, Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 2  When the menace known as the Joker wreaks havo...        84.0
#
#             Director           Star1           Star2          Star3  \
# 0     Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 2  Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
#
#             Star4  No_of_Votes        Gross
# 0  William Sadler      2343110   28341469.0
# 2   Michael Caine      2303232  534858444.0

# %%
# look at the oldest movie in this dataset. How to see the latest?
df_movies.sort_values(by='Released_Year', ascending=False).head()
# Out:
#                                            Poster_Link  \
# 613  https://m.media-amazon.com/images/M/MV5BOTNjM2...
# 18   https://m.media-amazon.com/images/M/MV5BNjViNW...
# 464  https://m.media-amazon.com/images/M/MV5BNmI0MT...
# 205  https://m.media-amazon.com/images/M/MV5BZGE1MD...
# 612  https://m.media-amazon.com/images/M/MV5BYjYzOG...
#
#                    Series_Title  Released_Year Certificate  Runtime  \
# 613                        Druk         2020.0         NaN  117 min
# 18                     Hamilton         2020.0       PG-13  160 min
# 464                 Dil Bechara         2020.0          UA  101 min
# 205                        Soul         2020.0           U  100 min
# 612  The Trial of the Chicago 7         2020.0           R  129 min
#
#                             Genre  IMDB_Rating  \
# 613                 Comedy, Drama          7.8
# 18      Biography, Drama, History          8.6
# 464        Comedy, Drama, Romance          7.9
# 205  Animation, Adventure, Comedy          8.1
# 612      Drama, History, Thriller          7.8
#
#                                               Overview  Meta_score  \
# 613  Four friends, all high school teachers, test a...        81.0
# 18   The real life of one of America's foremost fou...        90.0
# 464  The emotional journey of two hopelessly in lov...         NaN
# 205  After landing the gig of a lifetime, a New Yor...        83.0
# 612  The story of 7 people on trial stemming from v...        77.0
#
#               Director                 Star1             Star2  \
# 613  Thomas Vinterberg        Mads Mikkelsen  Thomas Bo Larsen
# 18         Thomas Kail    Lin-Manuel Miranda      Phillipa Soo
# 464     Mukesh Chhabra  Sushant Singh Rajput    Sanjana Sanghi
# 205        Pete Docter           Kemp Powers        Jamie Foxx
# 612       Aaron Sorkin        Eddie Redmayne        Alex Sharp
#
#                  Star3                   Star4  No_of_Votes  Gross
# 613     Magnus Millang             Lars Ranthe        33931    NaN
# 18     Leslie Odom Jr.  Renée Elise Goldsberry        55291    NaN
# 464         Sahil Vaid      Saswata Chatterjee       111478    NaN
# 205           Tina Fey           Graham Norton       159171    NaN
# 612  Sacha Baron Cohen           Jeremy Strong        89896    NaN

# %%
# group the movies based on the first actor and sort by the number of movies
# they have played in
df_movies.groupby('Star1').size().sort_values()
# Out:
# Star1
# Jonathan Pryce       1
# Martin Freeman       1
# Marjane Satrapi      1
# Marion Cotillard     1
# Mario Casas          1
#                     ..
# Humphrey Bogart      9
# Al Pacino           10
# Clint Eastwood      10
# Robert De Niro      11
# Tom Hanks           12
# Length: 660, dtype: int64

# %%
# What are the Certificate types?
df_movies.Certificate.unique()
# Out:
# array(['A', 'UA', 'U', 'PG-13', 'R', nan, 'PG', 'G', 'Passed', 'TV-14',
#        '16', 'TV-MA', 'Unrated', 'GP', 'Approved', 'TV-PG', 'U/A'],
#       dtype=object)

# %%
# Which movie descriptions have NASA in their Overview?
df_movies[df_movies.Overview.str.contains('NASA')]
# Out:
#                                            Poster_Link    Series_Title  \
# 575  https://m.media-amazon.com/images/M/MV5BMzg2Mz...  Hidden Figures
# 966  https://m.media-amazon.com/images/M/MV5BNjEzYj...       Apollo 13
#
#      Released_Year Certificate  Runtime                      Genre  \
# 575         2016.0          UA  127 min  Biography, Drama, History
# 966            NaN           U  140 min  Adventure, Drama, History
#
#      IMDB_Rating                                           Overview  \
# 575          7.8  The story of a team of female African-American...
# 966          7.6  NASA must devise a strategy to return Apollo 1...
#
#      Meta_score        Director             Star1            Star2  \
# 575        74.0  Theodore Melfi  Taraji P. Henson  Octavia Spencer
# 966        77.0      Ron Howard         Tom Hanks      Bill Paxton
#
#              Star3          Star4  No_of_Votes        Gross
# 575  Janelle Monáe  Kevin Costner       200876  169607287.0
# 966    Kevin Bacon    Gary Sinise       269197  173837933.0

# %%
# create a function that changes "The Dark Knight" movie name to "Batman"
# in the Series_Title

def change_spelling(name):
    """
    changing name of The Dark Knight to Batman
    """
    if name == "The Dark Knight": return "Batman"
    else: return name


# apply the changes on Series_Title
df_movies.loc[:, 'Series_Title'] = df_movies.loc[:, 'Series_Title'].apply(lambda x: change_spelling(x))

# %%
# print the 'Series_Title' in df_movies to see the value has changed
df_movies.loc[:, 'Series_Title']
# Out:
# 0      The Shawshank Redemption
# 1                 The Godfather
# 2                        Batman
# 3        The Godfather: Part II
# 4                  12 Angry Men
#                  ...
# 995      Breakfast at Tiffany's
# 996                       Giant
# 997       From Here to Eternity
# 998                    Lifeboat
# 999                The 39 Steps
# Name: Series_Title, Length: 1000, dtype: object

# %% [markdown]
# ### Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# data manipulation
# create a column called decade that has the decade in which the house was built
df.loc[:, 'decade'] = df.YearBuilt // 10 * 10
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0            Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1            Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2            Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3            Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4            Lvl    AllPub       FR2       Gtl      NoRidge       Norm
# ...          ...       ...       ...       ...          ...        ...
# 1455         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1456         Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 1457         Lvl    AllPub    Inside       Gtl      Crawfor       Norm
# 1458         Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 1459         Lvl    AllPub    Inside       Gtl      Edwards       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0          Norm     1Fam    2Storey            7            5       2003
# 1          Norm     1Fam    1Storey            6            8       1976
# 2          Norm     1Fam    2Storey            7            5       2001
# 3          Norm     1Fam    2Storey            7            5       1915
# 4          Norm     1Fam    2Storey            8            5       2000
# ...         ...      ...        ...          ...          ...        ...
# 1455       Norm     1Fam    2Storey            6            5       1999
# 1456       Norm     1Fam    1Storey            6            6       1978
# 1457       Norm     1Fam    2Storey            7            9       1941
# 1458       Norm     1Fam    1Storey            5            6       1950
# 1459       Norm     1Fam    1Storey            5            6       1965
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0             2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1             1976     Gable  CompShg     MetalSd     MetalSd       None
# 2             2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3             1970     Gable  CompShg     Wd Sdng     Wd Shng       None
# 4             2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
# ...            ...       ...      ...         ...         ...        ...
# 1455          2000     Gable  CompShg     VinylSd     VinylSd       None
# 1456          1988     Gable  CompShg     Plywood     Plywood      Stone
# 1457          2006     Gable  CompShg     CemntBd     CmentBd       None
# 1458          1996       Hip  CompShg     MetalSd     MetalSd       None
# 1459          1965     Gable  CompShg     HdBoard     HdBoard       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 0          196.0        Gd        TA      PConc       Gd       TA
# 1            0.0        TA        TA     CBlock       Gd       TA
# 2          162.0        Gd        TA      PConc       Gd       TA
# 3            0.0        TA        TA     BrkTil       TA       Gd
# 4          350.0        Gd        TA      PConc       Gd       TA
# ...          ...       ...       ...        ...      ...      ...
# 1455         0.0        TA        TA      PConc       Gd       TA
# 1456       119.0        TA        TA     CBlock       Gd       TA
# 1457         0.0        Ex        Gd      Stone       TA       Gd
# 1458         0.0        TA        TA     CBlock       TA       TA
# 1459         0.0        Gd        TA     CBlock       TA       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 0              No          GLQ         706          Unf           0
# 1              Gd          ALQ         978          Unf           0
# 2              Mn          GLQ         486          Unf           0
# 3              No          ALQ         216          Unf           0
# 4              Av          GLQ         655          Unf           0
# ...           ...          ...         ...          ...         ...
# 1455           No          Unf           0          Unf           0
# 1456           No          ALQ         790          Rec         163
# 1457           No          GLQ         275          Unf           0
# 1458           Mn          GLQ          49          Rec        1029
# 1459           No          BLQ         830          LwQ         290
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 0           150          856    GasA        Ex          Y      SBrkr
# 1           284         1262    GasA        Ex          Y      SBrkr
# 2           434          920    GasA        Ex          Y      SBrkr
# 3           540          756    GasA        Gd          Y      SBrkr
# 4           490         1145    GasA        Ex          Y      SBrkr
# ...         ...          ...     ...       ...        ...        ...
# 1455        953          953    GasA        Ex          Y      SBrkr
# 1456        589         1542    GasA        TA          Y      SBrkr
# 1457        877         1152    GasA        Ex          Y      SBrkr
# 1458          0         1078    GasA        Gd          Y      FuseA
# 1459        136         1256    GasA        Gd          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 0          856       854             0       1710             1             0
# 1         1262         0             0       1262             0             1
# 2          920       866             0       1786             1             0
# 3          961       756             0       1717             1             0
# 4         1145      1053             0       2198             1             0
# ...        ...       ...           ...        ...           ...           ...
# 1455       953       694             0       1647             0             0
# 1456      2073         0             0       2073             1             0
# 1457      1188      1152             0       2340             0             0
# 1458      1078         0             0       1078             1             0
# 1459      1256         0             0       1256             1             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 0            2         1             3             1          Gd
# 1            2         0             3             1          TA
# 2            2         1             3             1          Gd
# 3            1         0             3             1          Gd
# 4            2         1             4             1          Gd
# ...        ...       ...           ...           ...         ...
# 1455         2         1             3             1          TA
# 1456         2         0             3             1          TA
# 1457         2         0             4             1          Gd
# 1458         1         0             2             1          Gd
# 1459         1         1             3             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 0                8        Typ           0         NaN     Attchd       2003.0
# 1                6        Typ           1          TA     Attchd       1976.0
# 2                6        Typ           1          TA     Attchd       2001.0
# 3                7        Typ           1          Gd     Detchd       1998.0
# 4                9        Typ           1          TA     Attchd       2000.0
# ...            ...        ...         ...         ...        ...          ...
# 1455             7        Typ           1          TA     Attchd       1999.0
# 1456             7       Min1           2          TA     Attchd       1978.0
# 1457             9        Typ           2          Gd     Attchd       1941.0
# 1458             5        Typ           0         NaN     Attchd       1950.0
# 1459             6        Typ           0         NaN     Attchd       1965.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 0             RFn           2         548         TA         TA          Y
# 1             RFn           2         460         TA         TA          Y
# 2             RFn           2         608         TA         TA          Y
# 3             Unf           3         642         TA         TA          Y
# 4             RFn           3         836         TA         TA          Y
# ...           ...         ...         ...        ...        ...        ...
# 1455          RFn           2         460         TA         TA          Y
# 1456          Unf           2         500         TA         TA          Y
# 1457          RFn           1         252         TA         TA          Y
# 1458          Unf           1         240         TA         TA          Y
# 1459          Fin           1         276         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 0              0           61              0          0            0
# 1            298            0              0          0            0
# 2              0           42              0          0            0
# 3              0           35            272          0            0
# 4            192           84              0          0            0
# ...          ...          ...            ...        ...          ...
# 1455           0           40              0          0            0
# 1456         349            0              0          0            0
# 1457           0           60              0          0            0
# 1458         366            0            112          0            0
# 1459         736           68              0          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 0            0    NaN    NaN         NaN        0       2    2008       WD
# 1            0    NaN    NaN         NaN        0       5    2007       WD
# 2            0    NaN    NaN         NaN        0       9    2008       WD
# 3            0    NaN    NaN         NaN        0       2    2006       WD
# 4            0    NaN    NaN         NaN        0      12    2008       WD
# ...        ...    ...    ...         ...      ...     ...     ...      ...
# 1455         0    NaN    NaN         NaN        0       8    2007       WD
# 1456         0    NaN  MnPrv         NaN        0       2    2010       WD
# 1457         0    NaN  GdPrv        Shed     2500       5    2010       WD
# 1458         0    NaN    NaN         NaN        0       4    2010       WD
# 1459         0    NaN    NaN         NaN        0       6    2008       WD
#
#      SaleCondition  SalePrice  decade
# 0           Normal     208500    2000
# 1           Normal     181500    1970
# 2           Normal     223500    2000
# 3          Abnorml     140000    1910
# 4           Normal     250000    2000
# ...            ...        ...     ...
# 1455        Normal     175000    1990
# 1456        Normal     210000    1970
# 1457        Normal     266500    1940
# 1458        Normal     142125    1950
# 1459        Normal     147500    1960
#
# [1460 rows x 82 columns]

# %%
# Using groupby(), plot the number of houses built each decade

df.groupby(by='decade').size().plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='decade'>

# %%
# Using groupby(), plot the number of 2Storey houses built each decade

df_2storey = df[df['HouseStyle']=='2Storey'].reset_index(drop=True)
df_2storey
df_2storey.groupby(by='decade').size().plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='decade'>

# %% [markdown]
# ### df.corr()
#
# The correlation matrix is a square matrix that displays the pairwise correlations between all numeric columns in the DataFrame. It is a valuable tool for understanding the relationships and dependencies between different variables in your dataset.
#
# The correlation coefficient, which ranges from -1 to 1, quantifies the strength and direction of the linear relationship between two variables:
#
# A value of 1 indicates a perfect positive linear correlation, meaning that as one variable increases, the other also increases proportionally.
# A value of -1 indicates a perfect negative linear correlation, meaning that as one variable increases, the other decreases proportionally.
# A value close to 0 indicates a weak or no linear correlation between the variables.

# %%
# Correlation map to see how features are correlated with SalePrice
corrmat = df.corr()
plt.subplots(figsize=(12,9))
sns.heatmap(corrmat, vmax=0.9, square=True, cmap='coolwarm')
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_11336\1710188972.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrmat = df.corr()
# <AxesSubplot: >

# %%
# plot GrLivArea against SalePrice
# do you see anything out of the ordinary?
fig, ax = plt.subplots()
ax.scatter(x = df['GrLivArea'], y = df['SalePrice'])
plt.ylabel('SalePrice', fontsize=13)
plt.xlabel('GrLivArea', fontsize=13)
plt.show()

# %%
#Deleting outliers
df = df.drop(df[df['GrLivArea']>4000].index)

fig, ax = plt.subplots()
ax.scatter(df['GrLivArea'], df['SalePrice'])
plt.ylabel('SalePrice', fontsize=13)
plt.xlabel('GrLivArea', fontsize=13)
plt.show()

# %% [markdown]
#  ### displot (short for "distribution plot")
#
#  This is a function used to visualize the univariate distribution of a dataset. It allows you to plot the distribution of a single continuous variable, providing insights into its underlying data distribution, including the shape, central tendency, and spread of the data.
#
#  **data** is the data you want to visualize. It can be a Pandas Series, NumPy array, or a list containing your dataset.
#
# **bins** (optional) controls the number of bins or intervals into which the data is divided for the histogram. More bins provide finer granularity.
#
# **kde** (optional) stands for "Kernel Density Estimation" and is a way to estimate the probability density function of the data. Setting it to True adds a smoothed curve to the plot, which can provide additional insights into the data's distribution.

# %%
# let's make a histogram for sales
sns.displot(df['SalePrice'], kde=True)

# %% [markdown]
# The catplot function is a powerful and flexible way to create categorical plots. Categorical plots are used to visualize the distribution of one variable within different categories or the relationship between two categorical variables.

# %%
feature = 'OverallQual' # add the name of the column to this list - 'MoSold'

sns.set_style('whitegrid')
sns.catplot(x=feature, kind="count", palette="PuRd_r", data=df)

# %% [markdown]
# ### Your Turn

# %%
# create a column called decade that has the decade in which the house was built
df_movies.loc[:, 'decade'] = df_movies.Released_Year // 10 * 10
df_movies
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title  Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption         1994.0           A  142 min
# 1               The Godfather         1972.0           A  175 min
# 2                      Batman         2008.0          UA  152 min
# 3      The Godfather: Part II         1974.0           A  202 min
# 4                12 Angry Men         1957.0           U   96 min
# ..                        ...            ...         ...      ...
# 995    Breakfast at Tiffany's         1961.0           A  115 min
# 996                     Giant         1956.0           G  201 min
# 997     From Here to Eternity         1953.0      Passed  118 min
# 998                  Lifeboat         1944.0         NaN   97 min
# 999              The 39 Steps         1935.0         NaN   86 min
#
#                         Genre  IMDB_Rating  \
# 0                       Drama          9.3
# 1                Crime, Drama          9.2
# 2        Action, Crime, Drama          9.0
# 3                Crime, Drama          9.0
# 4                Crime, Drama          9.0
# ..                        ...          ...
# 995    Comedy, Drama, Romance          7.6
# 996            Drama, Western          7.6
# 997       Drama, Romance, War          7.6
# 998                Drama, War          7.6
# 999  Crime, Mystery, Thriller          7.6
#
#                                               Overview  Meta_score  \
# 0    Two imprisoned men bond over a number of years...        80.0
# 1    An organized crime dynasty's aging patriarch t...       100.0
# 2    When the menace known as the Joker wreaks havo...        84.0
# 3    The early life and career of Vito Corleone in ...        90.0
# 4    A jury holdout attempts to prevent a miscarria...        96.0
# ..                                                 ...         ...
# 995  A young New York socialite becomes interested ...        76.0
# 996  Sprawling epic covering the life of a Texas ca...        84.0
# 997  In Hawaii in 1941, a private is cruelly punish...        85.0
# 998  Several survivors of a torpedoed merchant ship...        78.0
# 999  A man in London tries to help a counter-espion...        93.0
#
#                  Director              Star1              Star2  \
# 0          Frank Darabont        Tim Robbins     Morgan Freeman
# 1    Francis Ford Coppola      Marlon Brando          Al Pacino
# 2       Christopher Nolan     Christian Bale       Heath Ledger
# 3    Francis Ford Coppola          Al Pacino     Robert De Niro
# 4            Sidney Lumet        Henry Fonda        Lee J. Cobb
# ..                    ...                ...                ...
# 995         Blake Edwards     Audrey Hepburn     George Peppard
# 996        George Stevens   Elizabeth Taylor        Rock Hudson
# 997        Fred Zinnemann     Burt Lancaster   Montgomery Clift
# 998      Alfred Hitchcock  Tallulah Bankhead        John Hodiak
# 999      Alfred Hitchcock       Robert Donat  Madeleine Carroll
#
#               Star3           Star4  No_of_Votes        Gross  decade
# 0        Bob Gunton  William Sadler      2343110   28341469.0  1990.0
# 1        James Caan    Diane Keaton      1620367  134966411.0  1970.0
# 2     Aaron Eckhart   Michael Caine      2303232  534858444.0  2000.0
# 3     Robert Duvall    Diane Keaton      1129952   57300000.0  1970.0
# 4     Martin Balsam    John Fiedler       689845    4360000.0  1950.0
# ..              ...             ...          ...          ...     ...
# 995   Patricia Neal     Buddy Ebsen       166544          NaN  1960.0
# 996      James Dean   Carroll Baker        34075          NaN  1950.0
# 997    Deborah Kerr      Donna Reed        43374   30500000.0  1950.0
# 998   Walter Slezak  William Bendix        26471          NaN  1940.0
# 999  Lucie Mannheim  Godfrey Tearle        51853          NaN  1930.0
#
# [1000 rows x 17 columns]

# %%
# Using groupby(), plot the number of movies
# that have been made each decade in the history of cinema.

df_movies.groupby(by='decade').size().plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='decade'>

# %%
# build the correlation matrix and plot it with seaborn!
#Correlation map to see how features are correlated with SalePrice
corrmat = df_movies.corr()
plt.subplots(figsize=(12,9))
sns.heatmap(corrmat, vmax=0.9, square=True)
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_11336\3373372082.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrmat = df_movies.corr()
# <AxesSubplot: >

# %%
# histogram
sns.displot(df_movies['No_of_Votes'], kde=True)

# %% [markdown]
#  ## Missing Values
#  When handling these null values we have to divide them into three categories. [Reference](https://cjasn.asnjournals.org/content/9/7/1328.abstract)
#
#
# ![pic](https://github.com/mitramir55/teaching_material/blob/master/missing%20values.png?raw=true)
#
#
# **Missing Completely at Random (MCAR):** This means that there is no relationship between the missing values themselves and any other feature or observation in the dataset. These are just missing randomly and without any pattern. Like when a questionnaire is lost or some parts of a survey paper are soaked and you cannot read what it's saying. Therefore we can simply ignore them.
#
# **Missing at Random (MAR):** Means there is a pattern and relationship between the missing values and the observed values, like when the survey is about mental and physical health, male participants are less likely to know their waist circumference or boob size. We can again ignore these missing values and drop the feature or examples from our dataset. In this case we say that missing values are only related to the observed features (gender).
#
# **Missing Not at Random (MNAR):** This is a missing value that cannot and should not be ignored. We have to model and see when were the values missing and what was the reason for it. For instance, men might not answer questions about depression because of their depression. In this case we say that the missing values are related to themselves (depression) as well as to the observed features (gender).

# %%
# how to see the total number of null values?
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# decade             0
# Length: 82, dtype: int64

# %%
# which one has the most null values?
df.isnull().sum().sort_values(ascending=False)
# Out:
# PoolQC         1451
# MiscFeature    1402
# Alley          1365
# Fence          1176
# FireplaceQu     690
#                ...
# ExterQual         0
# Exterior2nd       0
# Exterior1st       0
# RoofMatl          0
# decade            0
# Length: 82, dtype: int64

# %%
# a function for an interpretable visualization of nulls
def detect_nulls(df, n=30):
    """
    A function for viewing the null values present in the dataset
    input: takes in a dataframe and the n for the n most empty columns
    output: a dataframe with the count and precentage of nulls
    """
    df_nulls = df.isnull().sum()
    df_nulls = pd.DataFrame(np.c_[df_nulls, np.round(df_nulls/len(df) *100, 2)],
                                    columns=['count', 'percentage'], index = df_nulls.index)
    df_nulls.sort_values(by = df_nulls.columns[0], ascending=False, inplace = True)

    df_nulls = df_nulls.loc[[i for i in df_nulls.index if (df_nulls.loc[i, :] != 0).any() & (i not in ['SalePrice'])]]

    print('How many features had at least one null value?', len(df_nulls))
    print('{} most empty features of all:'.format(df_nulls.index[0]))
    return df_nulls[:n]

# %%
detect_nulls(df, n=40)
# Out:
# How many features had at least one null value? 19
# PoolQC most empty features of all:
#                count  percentage
# PoolQC        1451.0       99.66
# MiscFeature   1402.0       96.29
# Alley         1365.0       93.75
# Fence         1176.0       80.77
# FireplaceQu    690.0       47.39
# LotFrontage    259.0       17.79
# GarageType      81.0        5.56
# GarageYrBlt     81.0        5.56
# GarageCond      81.0        5.56
# GarageQual      81.0        5.56
# GarageFinish    81.0        5.56
# BsmtFinType2    38.0        2.61
# BsmtExposure    38.0        2.61
# BsmtQual        37.0        2.54
# BsmtCond        37.0        2.54
# BsmtFinType1    37.0        2.54
# MasVnrType       8.0        0.55
# MasVnrArea       8.0        0.55
# Electrical       1.0        0.07

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0            Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1            Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2            Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3            Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4            Lvl    AllPub       FR2       Gtl      NoRidge       Norm
# ...          ...       ...       ...       ...          ...        ...
# 1455         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1456         Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 1457         Lvl    AllPub    Inside       Gtl      Crawfor       Norm
# 1458         Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 1459         Lvl    AllPub    Inside       Gtl      Edwards       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0          Norm     1Fam    2Storey            7            5       2003
# 1          Norm     1Fam    1Storey            6            8       1976
# 2          Norm     1Fam    2Storey            7            5       2001
# 3          Norm     1Fam    2Storey            7            5       1915
# 4          Norm     1Fam    2Storey            8            5       2000
# ...         ...      ...        ...          ...          ...        ...
# 1455       Norm     1Fam    2Storey            6            5       1999
# 1456       Norm     1Fam    1Storey            6            6       1978
# 1457       Norm     1Fam    2Storey            7            9       1941
# 1458       Norm     1Fam    1Storey            5            6       1950
# 1459       Norm     1Fam    1Storey            5            6       1965
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0             2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1             1976     Gable  CompShg     MetalSd     MetalSd       None
# 2             2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3             1970     Gable  CompShg     Wd Sdng     Wd Shng       None
# 4             2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
# ...            ...       ...      ...         ...         ...        ...
# 1455          2000     Gable  CompShg     VinylSd     VinylSd       None
# 1456          1988     Gable  CompShg     Plywood     Plywood      Stone
# 1457          2006     Gable  CompShg     CemntBd     CmentBd       None
# 1458          1996       Hip  CompShg     MetalSd     MetalSd       None
# 1459          1965     Gable  CompShg     HdBoard     HdBoard       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 0          196.0        Gd        TA      PConc       Gd       TA
# 1            0.0        TA        TA     CBlock       Gd       TA
# 2          162.0        Gd        TA      PConc       Gd       TA
# 3            0.0        TA        TA     BrkTil       TA       Gd
# 4          350.0        Gd        TA      PConc       Gd       TA
# ...          ...       ...       ...        ...      ...      ...
# 1455         0.0        TA        TA      PConc       Gd       TA
# 1456       119.0        TA        TA     CBlock       Gd       TA
# 1457         0.0        Ex        Gd      Stone       TA       Gd
# 1458         0.0        TA        TA     CBlock       TA       TA
# 1459         0.0        Gd        TA     CBlock       TA       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 0              No          GLQ         706          Unf           0
# 1              Gd          ALQ         978          Unf           0
# 2              Mn          GLQ         486          Unf           0
# 3              No          ALQ         216          Unf           0
# 4              Av          GLQ         655          Unf           0
# ...           ...          ...         ...          ...         ...
# 1455           No          Unf           0          Unf           0
# 1456           No          ALQ         790          Rec         163
# 1457           No          GLQ         275          Unf           0
# 1458           Mn          GLQ          49          Rec        1029
# 1459           No          BLQ         830          LwQ         290
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 0           150          856    GasA        Ex          Y      SBrkr
# 1           284         1262    GasA        Ex          Y      SBrkr
# 2           434          920    GasA        Ex          Y      SBrkr
# 3           540          756    GasA        Gd          Y      SBrkr
# 4           490         1145    GasA        Ex          Y      SBrkr
# ...         ...          ...     ...       ...        ...        ...
# 1455        953          953    GasA        Ex          Y      SBrkr
# 1456        589         1542    GasA        TA          Y      SBrkr
# 1457        877         1152    GasA        Ex          Y      SBrkr
# 1458          0         1078    GasA        Gd          Y      FuseA
# 1459        136         1256    GasA        Gd          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 0          856       854             0       1710             1             0
# 1         1262         0             0       1262             0             1
# 2          920       866             0       1786             1             0
# 3          961       756             0       1717             1             0
# 4         1145      1053             0       2198             1             0
# ...        ...       ...           ...        ...           ...           ...
# 1455       953       694             0       1647             0             0
# 1456      2073         0             0       2073             1             0
# 1457      1188      1152             0       2340             0             0
# 1458      1078         0             0       1078             1             0
# 1459      1256         0             0       1256             1             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 0            2         1             3             1          Gd
# 1            2         0             3             1          TA
# 2            2         1             3             1          Gd
# 3            1         0             3             1          Gd
# 4            2         1             4             1          Gd
# ...        ...       ...           ...           ...         ...
# 1455         2         1             3             1          TA
# 1456         2         0             3             1          TA
# 1457         2         0             4             1          Gd
# 1458         1         0             2             1          Gd
# 1459         1         1             3             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 0                8        Typ           0         NaN     Attchd       2003.0
# 1                6        Typ           1          TA     Attchd       1976.0
# 2                6        Typ           1          TA     Attchd       2001.0
# 3                7        Typ           1          Gd     Detchd       1998.0
# 4                9        Typ           1          TA     Attchd       2000.0
# ...            ...        ...         ...         ...        ...          ...
# 1455             7        Typ           1          TA     Attchd       1999.0
# 1456             7       Min1           2          TA     Attchd       1978.0
# 1457             9        Typ           2          Gd     Attchd       1941.0
# 1458             5        Typ           0         NaN     Attchd       1950.0
# 1459             6        Typ           0         NaN     Attchd       1965.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 0             RFn           2         548         TA         TA          Y
# 1             RFn           2         460         TA         TA          Y
# 2             RFn           2         608         TA         TA          Y
# 3             Unf           3         642         TA         TA          Y
# 4             RFn           3         836         TA         TA          Y
# ...           ...         ...         ...        ...        ...        ...
# 1455          RFn           2         460         TA         TA          Y
# 1456          Unf           2         500         TA         TA          Y
# 1457          RFn           1         252         TA         TA          Y
# 1458          Unf           1         240         TA         TA          Y
# 1459          Fin           1         276         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 0              0           61              0          0            0
# 1            298            0              0          0            0
# 2              0           42              0          0            0
# 3              0           35            272          0            0
# 4            192           84              0          0            0
# ...          ...          ...            ...        ...          ...
# 1455           0           40              0          0            0
# 1456         349            0              0          0            0
# 1457           0           60              0          0            0
# 1458         366            0            112          0            0
# 1459         736           68              0          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 0            0    NaN    NaN         NaN        0       2    2008       WD
# 1            0    NaN    NaN         NaN        0       5    2007       WD
# 2            0    NaN    NaN         NaN        0       9    2008       WD
# 3            0    NaN    NaN         NaN        0       2    2006       WD
# 4            0    NaN    NaN         NaN        0      12    2008       WD
# ...        ...    ...    ...         ...      ...     ...     ...      ...
# 1455         0    NaN    NaN         NaN        0       8    2007       WD
# 1456         0    NaN  MnPrv         NaN        0       2    2010       WD
# 1457         0    NaN  GdPrv        Shed     2500       5    2010       WD
# 1458         0    NaN    NaN         NaN        0       4    2010       WD
# 1459         0    NaN    NaN         NaN        0       6    2008       WD
#
#      SaleCondition  SalePrice  decade
# 0           Normal     208500    2000
# 1           Normal     181500    1970
# 2           Normal     223500    2000
# 3          Abnorml     140000    1910
# 4           Normal     250000    2000
# ...            ...        ...     ...
# 1455        Normal     175000    1990
# 1456        Normal     210000    1970
# 1457        Normal     266500    1940
# 1458        Normal     142125    1950
# 1459        Normal     147500    1960
#
# [1456 rows x 82 columns]

# %%
# fill the null values in PoolQC and MiscFeature with None
df["PoolQC"] = df["PoolQC"].fillna("None")

# %%
# Write a for loop to fill the nulls values in
# 'MiscFeature', 'Fence', 'Alley', 'FireplaceQu'
# with None
for col in ('MiscFeature', 'Fence', 'Alley', 'FireplaceQu'):
    df[col] = df[col].fillna("None")

# %% [markdown]
# ### Stripplot
#
# x='category_column' specifies the categorical variable to be plotted on the x-axis. This is typically a column containing category labels.
# y='numeric_column' specifies the numeric variable to be plotted on the y-axis. This is the data you want to visualize within each category.
# data=data specifies the DataFrame containing your data.
#
# ### features to inspect -> 'PoolQC', 'MiscFeature', 'Alley'

# %%
# create a seaborn plot for the number of nulls
fig, ax = plt.subplots(figsize=(10, 5))
ax = sns.stripplot(x='PoolQC', y="SalePrice", data=df,
                    order=["None", "Fa", "Gd", "Ex"], size = 8)

# %%
# create a seaborn plot for the number of nulls
fig, ax = plt.subplots(figsize=(10, 5))
ax = sns.stripplot(x='MiscFeature', y="SalePrice", data=df, size = 8)

# %%
# Write a for loop to fill the nulls values in
# 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond'
# with None
for col in ('GarageType', 'GarageFinish', 'GarageQual', 'GarageCond'):
    df[col] = df[col].fillna('None')

# %%
# some have to be filled with zero
# 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF','TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath'
for col in ('BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF','TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath'):
    df[col] = df[col].fillna(0)

# %%
# what should be done for MSZoning (The general zoning classification)?

# %%
# let's plot the distribution

# Create a count plot
sns.countplot(data=df, x='MSZoning')

# Optional: Customize the plot
plt.title('Distribution of MSZoning')
plt.xlabel('Categories')
plt.ylabel('Count')

# Show the plot
plt.show()

# %%
# take a look at the most frequent value
df['MSZoning'].mode()[0]
# Out:
# 'RL'

# %%
df['MSZoning'] = df['MSZoning'].fillna(df['MSZoning'].mode()[0])

# %%
# so how to drop a column?
df.drop(columns=['PoolQC'], inplace=True)

# %%
# look at the Electrical column and see what can be done
df.Electrical.describe()
# Out:
# count      1455
# unique        5
# top       SBrkr
# freq       1330
# Name: Electrical, dtype: object

# %%
# see the values in this column
df.Electrical.unique()
# Out:
# array(['SBrkr', 'FuseF', 'FuseA', 'FuseP', 'Mix', nan], dtype=object)

# %%
# drop the record with null in it
df.dropna(subset=['Electrical'], inplace=True)

# %%
# check and see if we have dropped it correctly
df.Electrical.isna().sum()
# Out:
# 0

# %% [markdown]
# ### Your Turn

# %%
# see which columns have null?
df_movies.isna().sum()
# Out:
# Poster_Link        0
# Series_Title       0
# Released_Year      1
# Certificate      101
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Overview           0
# Meta_score       157
# Director           0
# Star1              0
# Star2              0
# Star3              0
# Star4              0
# No_of_Votes        0
# Gross            169
# decade             1
# dtype: int64

# %%
# drop the record that doesn't have Released_Year
df_movies.dropna(subset = 'Released_Year', inplace=True)

# %%
# inspect Meta_score
df_movies.Meta_score.describe()
# Out:
# count    842.000000
# mean      77.972684
# std       12.383410
# min       28.000000
# 25%       70.000000
# 50%       79.000000
# 75%       87.000000
# max      100.000000
# Name: Meta_score, dtype: float64

# %%
# fill it with the mean value
df_movies.Meta_score.fillna(value='77.9', inplace=True)

# %%
# see if we have any null values
df_movies.Meta_score.isna().sum()
# Out:
# 0

# %% [markdown]
# ### Reference
#
# * Brandon Rhodes - Pandas From The Ground Up - PyCon 2015: [link](https://www.youtube.com/watch?v=5JnMutdy6Fw&list=PL2vN4d3B5vi5gCdw4I-RAJonYAhH7k8bp&ab_channel=PyCon2015)
# * Missing values – Mitra’s Kaggle Tutorial: [link](https://www.kaggle.com/code/mitramir5/missing-values-ordinal-data-and-stories)
# * Crash Course Statistics: [link](https://www.youtube.com/watch?v=zouPoc49xbk&list=PL8dPuuaLjXtNM_Y-bUAhblSAdWRnmBUcr&ab_channel=CrashCourse)
